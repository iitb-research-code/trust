# %% [markdown]
# # Targeted Selection Demo For Biomedical Datasets With Rare Classes

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Imports

# %%
import time
import random
import datetime
import copy
import numpy as np
from tabulate import tabulate
import os
import csv
import json
import subprocess
import sys
import PIL.Image as Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.models as models
from matplotlib import pyplot as plt

sys.path.append('/home/venkat/trust/')

from trust.utils.models.resnet import ResNet18
from trust.utils.models.resnet import ResNet50
from trust.utils.custom_dataset_medmnist import load_biodataset_custom
from torch.utils.data import Subset
from torch.autograd import Variable
import tqdm
from math import floor
from sklearn.metrics.pairwise import cosine_similarity, pairwise_distances
from trust.strategies.smi import SMI
from trust.strategies.random_sampling import RandomSampling
from trust.strategies.wassal import WASSAL
from trust.strategies.wassal_refrain import WASSAL_Refrain
from trust.strategies.wassal_weighted import WASSAL_Weighted
from trust.strategies.wassal_hybrid import WASSAL_Hybrid

sys.path.append('/home/venkat/trust/')

# from distl.distil.scalable_active_learning_strategies.entropy_sampling import EntropySampling
# from distil.distil.scalable_active_learning_strategies.badge import BADGE

seed=42
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
from trust.utils.utils import *
from trust.utils.viz import tsne_smi

# %% [markdown]
# ### Helper functions

# %%
def model_eval_loss(data_loader, model, criterion):
    total_loss = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(data_loader):
            inputs, targets = inputs.to(device), targets.to(device, non_blocking=True)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item()
    return total_loss

def init_weights(m):
    if isinstance(m, nn.Conv2d):
        torch.nn.init.xavier_uniform_(m.weight)
    elif isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
        m.bias.data.fill_(0.01)

def weight_reset(m):
    if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
        m.reset_parameters()
                
def create_model(name, num_cls, device, embedding_type):
    if name == 'ResNet18':
        if embedding_type == "gradients":
            model = ResNet18(num_cls)
        else:
            model = models.resnet18()
    elif name == 'ResNet50':
        if embedding_type == "gradients":
            model = ResNet50(num_cls)
        else:
            model = models.resnet50()
    elif name == 'MnistNet':
        model = MnistNet()
    elif name == 'ResNet164':
        model = ResNet164(num_cls)
    model.apply(init_weights)
    model = model.to(device)
    return model

def loss_function():
    criterion = nn.CrossEntropyLoss()
    criterion_nored = nn.CrossEntropyLoss(reduction='none')
    return criterion, criterion_nored

def optimizer_with_scheduler(model, num_epochs, learning_rate, m=0.9, wd=5e-4):
    optimizer = optim.SGD(model.parameters(), lr=learning_rate,
                          momentum=m, weight_decay=wd)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
    return optimizer, scheduler

def optimizer_without_scheduler(model, learning_rate, m=0.9, wd=5e-4):
#     optimizer = optim.Adam(model.parameters(),weight_decay=wd)
    optimizer = optim.SGD(model.parameters(), lr=learning_rate,
                          momentum=m, weight_decay=wd)
    return optimizer

def generate_cumulative_timing(mod_timing):
    tmp = 0
    mod_cum_timing = np.zeros(len(mod_timing))
    for i in range(len(mod_timing)):
        tmp += mod_timing[i]
        mod_cum_timing[i] = tmp
    return mod_cum_timing/3600

def displayTable(val_err_log, tst_err_log):
    col1 = [str(i) for i in range(10)]
    val_acc = [str(100-i) for i in val_err_log]
    tst_acc = [str(100-i) for i in tst_err_log]
    table = [col1, val_acc, tst_acc]
    table = map(list, zip(*table))
    print(tabulate(table, headers=['Class', 'Val Accuracy', 'Test Accuracy'], tablefmt='orgtbl'))

def find_err_per_class(test_set, val_set, final_val_classifications, final_val_predictions, final_tst_classifications, 
                       final_tst_predictions, saveDir, prefix):
    val_err_idx = list(np.where(np.array(final_val_classifications) == False)[0])
    tst_err_idx = list(np.where(np.array(final_tst_classifications) == False)[0])
    val_class_err_idxs = []
    tst_err_log = []
    val_err_log = []
    for i in range(num_cls):
        tst_class_idxs = list(torch.where(torch.Tensor(test_set.targets) == i)[0].cpu().numpy())
        val_class_idxs = list(torch.where(torch.Tensor(val_set.targets.float()) == i)[0].cpu().numpy())
        #err classifications per class
        val_err_class_idx = set(val_err_idx).intersection(set(val_class_idxs))
        tst_err_class_idx = set(tst_err_idx).intersection(set(tst_class_idxs))
        if(len(val_class_idxs)>0):
            val_error_perc = round((len(val_err_class_idx)/len(val_class_idxs))*100,2)
        else:
            val_error_perc = 0
        tst_error_perc = round((len(tst_err_class_idx)/len(tst_class_idxs))*100,2)
#         print("val, test error% for class ", i, " : ", val_error_perc, tst_error_perc)
        val_class_err_idxs.append(val_err_class_idx)
        tst_err_log.append(tst_error_perc)
        val_err_log.append(val_error_perc)
    displayTable(val_err_log, tst_err_log)
    tst_err_log.append(sum(tst_err_log)/len(tst_err_log))
    val_err_log.append(sum(val_err_log)/len(val_err_log))
    return tst_err_log, val_err_log, val_class_err_idxs

def aug_train_subset(train_set, lake_set, true_lake_set, subset, lake_subset_idxs, budget, augrandom=False):
    all_lake_idx = list(range(len(lake_set)))
    if(not(len(subset)==budget) and augrandom):
        print("Budget not filled, adding ", str(int(budget) - len(subset)), " randomly.")
        remain_budget = int(budget) - len(subset)
        remain_lake_idx = list(set(all_lake_idx) - set(subset))
        random_subset_idx = list(np.random.choice(np.array(remain_lake_idx), size=int(remain_budget), replace=False))
        subset += random_subset_idx
    if str(type(true_lake_set.targets)) == "<class 'numpy.ndarray'>":
        lake_ss = SubsetWithTargets(true_lake_set, subset, torch.Tensor(true_lake_set.targets.astype(np.float))[subset])
    else:
        lake_ss = SubsetWithTargets(true_lake_set, subset, torch.Tensor(true_lake_set.targets.float())[subset])
    remain_lake_idx = list(set(all_lake_idx) - set(lake_subset_idxs))
    if str(type(true_lake_set.targets)) == "<class 'numpy.ndarray'>":
        remain_lake_set = SubsetWithTargets(lake_set, remain_lake_idx, torch.Tensor(lake_set.targets.astype(np.float))[remain_lake_idx])
    else:
        remain_lake_set = SubsetWithTargets(lake_set, remain_lake_idx, torch.Tensor(lake_set.targets.float())[remain_lake_idx])
    if str(type(true_lake_set.targets)) == "<class 'numpy.ndarray'>":
        remain_true_lake_set = SubsetWithTargets(true_lake_set, remain_lake_idx, torch.Tensor(true_lake_set.targets.astype(np.float))[remain_lake_idx])
    else:
        remain_true_lake_set = SubsetWithTargets(true_lake_set, remain_lake_idx, torch.Tensor(true_lake_set.targets.float())[remain_lake_idx])
#     print(len(lake_ss),len(remain_lake_set),len(lake_set))
    aug_train_set = torch.utils.data.ConcatDataset([train_set, lake_ss])
    aug_trainloader = torch.utils.data.DataLoader(train_set, batch_size=10, shuffle=True, pin_memory=True)
    return aug_train_set, remain_lake_set, remain_true_lake_set, lake_ss
                        
def getQuerySet(val_set, val_class_err_idxs, imb_cls_idx, miscls):
    imb_cls_idx=[1]
    miscls_idx = []
    if(miscls):
        for i in range(len(val_class_err_idxs)):
            if i in imb_cls_idx:
                miscls_idx += val_class_err_idxs[i]
        print("Total misclassified examples from imbalanced classes (Size of query set): ", len(miscls_idx))
    else:
        for i in imb_cls_idx:
            imb_cls_samples = list(torch.where(torch.Tensor(val_set.targets.float()) == i)[0].cpu().numpy())
            miscls_idx += imb_cls_samples
        print("Total samples from imbalanced classes as targets (Size of query set): ", len(miscls_idx))
    return Subset(val_set, miscls_idx), val_set.targets[miscls_idx]

def getPrivateSet(val_set, private_cls):
    private_cls=0
    val_loader = torch.utils.data.DataLoader(dataset=val_set, batch_size=len(val_set), shuffle=False)
    imgs, labels = next(iter(val_loader))
    private_idx = torch.where(labels==private_cls)[0]
    private_set = SubsetWithTargets(val_set, private_idx, labels[private_idx])
    return private_set

def getPerClassSel(lake_set, subset, num_cls):
    perClsSel = []
    if str(type(lake_set.targets)) == "<class 'numpy.ndarray'>":
        subset_cls = torch.Tensor(lake_set.targets.astype(np.float))[subset]
    else:
        subset_cls = torch.Tensor(lake_set.targets.float())[subset]
    for i in range(num_cls):
        cls_subset_idx = list(torch.where(subset_cls == i)[0].cpu().numpy())
        perClsSel.append(len(cls_subset_idx))
    return perClsSel

def print_final_results(res_dict, sel_cls_idx):
    print("Gain in overall test accuracy: ", res_dict['test_acc'][1]-res_dict['test_acc'][0])
    bf_sel_cls_acc = np.array(res_dict['all_class_acc'][0])[sel_cls_idx]
    af_sel_cls_acc = np.array(res_dict['all_class_acc'][1])[sel_cls_idx]
    print("Gain in targeted test accuracy: ", np.mean(af_sel_cls_acc-bf_sel_cls_acc))

class WeightedDataset(Dataset):
    def __init__(self, imgs, simplex_target, simplex_refrain):
        self.imgs = imgs
        self.simplex_target = simplex_target
        self.simplex_refrain = simplex_refrain

    def __len__(self):
        return len(self.imgs)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()
        image = self.imgs[idx]
        t = self.simplex_target[idx].item()
        r = self.simplex_refrain[idx].item()
        return (image, t, r)

def train_classifier_on_weighted_labels(args, model, optimizer, unlabeled_set, simplex_target, simplex_refrain):
    # print("============ Training with weights ==============")
    # print("shape of simplex_target:{}".format(simplex_target.shape))
    # print("shape of simplex_refrain:{}".format(simplex_refrain.shape))
    criterion, criterion_nored = loss_function()
    unlabeled_loader = torch.utils.data.DataLoader(dataset=unlabeled_set, batch_size=len(unlabeled_set), shuffle=False)
    unlabeled_imgs, u_labels = next(iter(unlabeled_loader))
    # print("shape of unlabeled_set:{}".format(unlabeled_imgs.shape))
    train_set = WeightedDataset(unlabeled_imgs, simplex_target, simplex_refrain)
    train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=200, shuffle=False)
    device = args['device']

    for epoch in range(1):
        # model.train()
        for (inputs, target_simplex, refrain_simplex) in train_loader:
            inputs = inputs.to(device)
            # print(inputs.shape)
            target_simplex, refrain_simplex = target_simplex.to(device), refrain_simplex.to(device)
            batch_size = len(inputs)
            target_labels = torch.tensor([args['target'] for i in range(batch_size)]).to(device)
            refrain_labels = torch.tensor([args['refrain'] for i in range(batch_size)]).to(device)

            optimizer.zero_grad()
            preds = model(inputs)
            target_loss_per_sample = criterion_nored(preds, target_labels)
            refrain_loss_per_sample = criterion_nored(preds, refrain_labels)
            total_loss = ((target_loss_per_sample*target_simplex) + (refrain_loss_per_sample*refrain_simplex)).sum()
            total_loss = args['weight']*total_loss
            total_loss.backward()
            optimizer.step()
    return (model, optimizer)

def getSimplexes(simplex_target, simplex_refrain, lake_subset_idx):
    all_idx = list(range(len(simplex_target)))
    rem_idx = list(set(all_idx)-set(lake_subset_idx))
    return simplex_target[rem_idx], simplex_refrain[rem_idx]

def analyze_simplex(args, unlabeled_set, simplex_target, simplex_refrain):
    unlabeled_loader = torch.utils.data.DataLoader(dataset=unlabeled_set, batch_size=len(unlabeled_set), shuffle=False)
    u_imgs, u_labels = next(iter(unlabeled_loader))
    u_imgs, u_labels = u_imgs.to(args['device']), u_labels.to(args['device'])
    nz_target_idx = simplex_target.nonzero()
    nz_refrain_idx = simplex_refrain.nonzero()
    num_nz_target = (u_labels[nz_target_idx]==args['target']).nonzero().shape[0]
    num_nz_refrain = (u_labels[nz_refrain_idx]==args['refrain']).nonzero().shape[0]
    print("no of target labels identified correctly: {}/{}".format(num_nz_target, nz_target_idx.shape[0]))
    print("no of refrain labels identified correctly: {}/{}".format(num_nz_refrain, nz_refrain_idx.shape[0]))
    target_idx = torch.where(u_labels==args['target'])
    target_weight = torch.sum(simplex_target[target_idx])
    refrain_idx = torch.where(u_labels==args['refrain'])
    refrain_weight = torch.sum(simplex_refrain[refrain_idx])
    print("Weight of target samples in simplex_target: {}".format(target_weight))
    print("Weight of refrain samples in simplex_refrain: {}".format(refrain_weight))

# %% [markdown]
# # Data, Model & Experimental Settings
# The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes.The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class. The training set contains 50,000 images and test set contains 10,000 images. We will use custom_dataset() function in Trust to simulated a class imbalance scenario using the split_cfg dictionary given below. We then use a ResNet18 model as our task DNN and train it on the simulated imbalanced version of the CIFAR-10 dataset. Next we perform targeted selection using various SMI functions and compare their gain in overall accuracy as well as on the imbalanced classes.

# %%
feature = "classimb"
device_id = 0
run="test_run"
# datadir = 'data/'
# datadir = '/data/medmnist' #contains the npz file of the data_name dataset listed below
datadir = '/media/data3.1/gan/data-selection-by-softsubsetting/data/pneumoniamnist/' #contains the npz file of the data_name dataset listed below
data_name = 'pneumoniamnist'
model_name = 'ResNet18'
learning_rate = 0.0003 #0.0003
computeClassErrorLog = True
device = "cuda:"+str(device_id) if torch.cuda.is_available() else "cpu"
miscls = True #Set to True if only the misclassified examples from the imbalanced classes is to be used
embedding_type = "gradients" #Type of the representation to use (gradients/features)
num_cls = 2
budget = 25
visualize_tsne = False
split_cfg = {"sel_cls_idx":[0,1],
             "per_imbclass_train":{0:100,1:5},
             "per_imbclass_val":{0:20,1:20},
             "per_imbclass_lake":{0:1050,1:53},
             "per_imbclass_test":{0:200,1:200}}
print("split_cfg:",split_cfg)
initModelPath = "./"+data_name + "_" + model_name + "_" + str(0.0003) + "_" + str(split_cfg["sel_cls_idx"])
# Out:
# split_cfg: {'sel_cls_idx': [0, 1], 'per_imbclass_train': {0: 100, 1: 5}, 'per_imbclass_val': {0: 20, 1: 20}, 'per_imbclass_lake': {0: 1050, 1: 53}, 'per_imbclass_test': {0: 200, 1: 200}}

# %%
# train_set, val_set, test_set, lake_set, sel_cls_idx, num_cls = load_biodataset_custom(datadir, data_name, feature, split_cfg, False, False)
# val_loader = torch.utils.data.DataLoader(dataset=val_set, batch_size=len(val_set), shuffle=False)
# imgs, labels = next(iter(val_loader))
# idx = torch.where(labels==0)[0]
# labels[idx]

# %% [markdown]
# # Targeted Selection Algorithm
# 1. Given: Initial Labeled set of Examples: 𝐸, large unlabeled dataset: 𝑈, A target subset/slice where we want to improve accuracy: 𝑇, Loss function 𝐿 for learning
# 2. Train model with loss $\mathcal L$ on labeled set $E$ and obtain parameters $\theta_E$
# 3. Compute the gradients $\{\nabla_{\theta_E} \mathcal L(x_i, y_i), i \in U\}$ (using hypothesized labels) and $\{\nabla_{\theta_E} \mathcal L(x_i, y_i), i \in T\}$.
# (This notebook uses gradients for representation. However, any other representation can be used. Trust also supports using features via the API.)
# 4. Compute the similarity kernels $S$ (this includes kernel of the elements within $U$, within $T$ and between $U$ and $T$) and define a submodular function $f$ and diversity function $g$
# 5. Compute subset $\hat{A}$ by mazximizing the SMI function: $\hat{A} \gets \max_{A \subseteq U, |A|\leq k} I_f(A;T) + \gamma g(A)$
# 6. Obtain the labels of the elements in $A^*$: $L(\hat{A})$
# 7. Train a model on the combined labeled set $E \cup L(\hat{A})$

# %%
def run_targeted_selection(dataset_name, datadir, feature, model_name, budget, split_cfg, learning_rate, run,
                device, computeErrorLog, strategy="SIM", sf="", h=0.2):

    #load the dataset in the class imbalance setting
    train_set, val_set, test_set, lake_set, sel_cls_idx, num_cls = load_biodataset_custom(datadir, dataset_name, feature, split_cfg, False, False)
    print("Indices of randomly selected classes for imbalance: ", sel_cls_idx)
    
    #Set batch size for train, validation and test datasets
    N = len(train_set)
    trn_batch_size = 20
    val_batch_size = 10
    tst_batch_size = 100

    #Create dataloaders
    trainloader = torch.utils.data.DataLoader(train_set, batch_size=trn_batch_size,
                                              shuffle=True, pin_memory=True)

    valloader = torch.utils.data.DataLoader(val_set, batch_size=val_batch_size, 
                                            shuffle=False, pin_memory=True)

    tstloader = torch.utils.data.DataLoader(test_set, batch_size=tst_batch_size,
                                             shuffle=False, pin_memory=True)
    
    lakeloader = torch.utils.data.DataLoader(lake_set, batch_size=tst_batch_size,
                                         shuffle=False, pin_memory=True)
    true_lake_set = copy.deepcopy(lake_set)
    # Budget for subset selection
    bud = budget
   
    # Variables to store accuracies
    num_rounds = 2 #The first round is for training the initial model and the second round is to train the final model
    fulltrn_losses = np.zeros(num_rounds)
    val_losses = np.zeros(num_rounds)
    tst_losses = np.zeros(num_rounds)
    timing = np.zeros(num_rounds)
    val_acc = np.zeros(num_rounds)
    full_trn_acc = np.zeros(num_rounds)
    tst_acc = np.zeros(num_rounds)
    final_tst_predictions = []
    final_tst_classifications = []
    best_val_acc = -1
    csvlog = []
    val_csvlog = []
    # Results logging file
    all_logs_dir = './results/' + dataset_name  + '/' + feature + '/'+  sf + '/' + str(bud) + '/' + str(run)
#     print("Saving results to: ", all_logs_dir)
#     subprocess.run(["mkdir", "-p", all_logs_dir]) #Uncomment for saving results
    exp_name = dataset_name + "_" + feature +  "_" + strategy + "_" + str(len(sel_cls_idx))  +"_" + sf +  '_budget:' + str(bud) + '_rounds:' + str(num_rounds) + '_runs' + str(run)

    #Create a dictionary for storing results and the experimental setting
    res_dict = {"dataset":data_name, 
                "feature":feature, 
                "sel_func":sf,
                "sel_budget":budget, 
                "num_selections":num_rounds-1, 
                "model":model_name, 
                "learning_rate":learning_rate, 
                "setting":split_cfg, 
                "all_class_acc":None, 
                "test_acc":[],
                "sel_per_cls":[], 
                "sel_cls_idx":sel_cls_idx}
    
    # Model Creation
    model = create_model(model_name, num_cls, device, embedding_type)
    model1 = create_model(model_name, num_cls, device, embedding_type)
    strategy_args = {'batch_size': 20, 'device':device, 'embedding_type':'gradients', 'keep_embedding':True,
                    'wd_num_epochs':50,'wd_lr':0.02,'verbose':False}
    unlabeled_lake_set = LabeledToUnlabeledDataset(lake_set)
    
    if(strategy == "AL"):
        if(sf=="badge"):
            strategy_sel = BADGE(train_set, unlabeled_lake_set, model, num_cls, strategy_args)
        elif(sf=="us"):
            strategy_sel = EntropySampling(train_set, unlabeled_lake_set, model, num_cls, strategy_args)
        elif(sf=="glister" or sf=="glister-tss"):
            strategy_sel = GLISTER(train_set, unlabeled_lake_set, model, num_cls, strategy_args, val_set, typeOf='rand', lam=0.1)
        elif(sf=="gradmatch-tss"):
            strategy_sel = GradMatchActive(train_set, unlabeled_lake_set, model, num_cls, strategy_args, val_set)
        elif(sf=="coreset"):
            strategy_sel = CoreSet(train_set, unlabeled_lake_set, model, num_cls, strategy_args)
        elif(sf=="leastconf"):
            strategy_sel = LeastConfidence(train_set, unlabeled_lake_set, model, num_cls, strategy_args)
        elif(sf=="margin"):
            strategy_sel = MarginSampling(train_set, unlabeled_lake_set, model, num_cls, strategy_args)
    if(strategy == "SIM"):
        strategy_args['smi_function'] = sf
        strategy_sel = SMI(train_set, unlabeled_lake_set, val_set, model, num_cls, strategy_args)
    if(strategy == "random"):
        strategy_sel = RandomSampling(train_set, unlabeled_lake_set, model, num_cls, strategy_args)
    if(strategy == "WASSAL"):
        strategy_args['verbose'] = True
        strategy_sel = WASSAL(train_set, unlabeled_lake_set, val_set, model, num_cls, strategy_args)
    if(strategy == "WASSAL_Refrain"):
        # strategy_args['verbose'] = True
        strategy_args['h'] = h
        strategy_args['target'] = 1
        strategy_args['refrain'] = 0
        strategy_sel = WASSAL_Refrain(train_set, unlabeled_lake_set, val_set, model, num_cls, strategy_args)
    if(strategy == "WASSAL_Weighted"):
        # strategy_args['verbose'] = True
        strategy_args['h'] = h
        strategy_args['target'] = 1
        strategy_args['refrain'] = 0
        strategy_args['weight'] = 2
        strategy_sel = WASSAL_Weighted(train_set, unlabeled_lake_set, val_set, model, num_cls, strategy_args)
    if(strategy == "WASSAL_Hybrid"):
        strategy_args['h'] = h
        strategy_args['target'] = 1
        strategy_args['refrain'] = 0
        strategy_args['weight'] = 2
        strategy_sel = WASSAL_Hybrid(train_set, unlabeled_lake_set, val_set, model, num_cls, strategy_args)

    # Loss Functions
    criterion, criterion_nored = loss_function()

    # Getting the optimizer and scheduler
    optimizer = optimizer_without_scheduler(model, learning_rate)

    for i in range(num_rounds):
        tst_loss = 0
        tst_correct = 0
        tst_total = 0
        val_loss = 0
        val_correct = 0
        val_total = 0
        
        if(i==0): #for 1st round
            print("Initial training epoch")
            if(os.path.exists(initModelPath)): #Read the initial trained model if it exists
                model.load_state_dict(torch.load(initModelPath, map_location=device))
                print("Init model loaded from disk, skipping init training: ", initModelPath)
                model.eval()
                with torch.no_grad():
                    final_val_predictions = []
                    final_val_classifications = []
                    for batch_idx, (inputs, targets) in enumerate(valloader):
                        inputs, targets = inputs.to(device), targets.to(device, non_blocking=True)
                        outputs = model(inputs)
                        loss = criterion(outputs, targets)
                        val_loss += loss.item()
                        _, predicted = outputs.max(1)
                        val_total += targets.size(0)
                        val_correct += predicted.eq(targets).sum().item()
                        final_val_predictions += list(predicted.cpu().numpy())
                        final_val_classifications += list(predicted.eq(targets).cpu().numpy())
  
                    final_tst_predictions = []
                    final_tst_classifications = []
                    for batch_idx, (inputs, targets) in enumerate(tstloader):
                        inputs, targets = inputs.to(device), targets.to(device, non_blocking=True)
                        outputs = model(inputs)
                        loss = criterion(outputs, targets)
                        tst_loss += loss.item()
                        _, predicted = outputs.max(1)
                        tst_total += targets.size(0)
                        tst_correct += predicted.eq(targets).sum().item()
                        final_tst_predictions += list(predicted.cpu().numpy())
                        final_tst_classifications += list(predicted.eq(targets).cpu().numpy())                
                    best_val_acc = (val_correct/val_total)
                    val_acc[i] = val_correct / val_total
                    tst_acc[i] = tst_correct / tst_total
                    val_losses[i] = val_loss
                    tst_losses[i] = tst_loss
                    res_dict["test_acc"].append(tst_acc[i]*100)
                continue
        
        else: # for remaining rounds
            #Remove true labels from the unlabeled dataset, the hypothesized labels are computed when select is called
            unlabeled_lake_set = LabeledToUnlabeledDataset(lake_set)
            strategy_sel.update_data(train_set, unlabeled_lake_set)
            #compute the error log before every selection
            if(computeErrorLog):
                tst_err_log, val_err_log, val_class_err_idxs = find_err_per_class(test_set, val_set, final_val_classifications, final_val_predictions, final_tst_classifications, final_tst_predictions, all_logs_dir, sf+"_"+str(bud))
                csvlog.append([100-x for x in tst_err_log])
                val_csvlog.append([100-x for x in val_err_log])
            ####SIM####
            if(strategy=='WASSAL'):
                if(feature=="classimb"):
                        #make a dataloader for the misclassifications - only for experiments with targets
                        miscls_set, miscls_set_targets = getQuerySet(val_set, val_class_err_idxs, sel_cls_idx, miscls)
                        strategy_sel.update_queries(miscls_set)

            if(strategy=="WASSAL_Refrain"):
                if(feature=="classimb"):
                    miscls_set, miscls_set_targets = getQuerySet(val_set, val_class_err_idxs, sel_cls_idx, miscls)
                    strategy_sel.update_queries(miscls_set)
                    private_set = getPrivateSet(val_set, 0)
                    strategy_sel.update_privates(private_set)
            
            if(strategy=="WASSAL_Weighted"):
                if(feature=="classimb"):
                    miscls_set, miscls_set_targets = getQuerySet(val_set, val_class_err_idxs, sel_cls_idx, miscls)
                    strategy_sel.update_queries(miscls_set)
                    private_set = getPrivateSet(val_set, 0)
                    strategy_sel.update_privates(private_set)
            
            if(strategy=="WASSAL_Hybrid"):
                if(feature=="classimb"):
                    miscls_set, miscls_set_targets = getQuerySet(val_set, val_class_err_idxs, sel_cls_idx, miscls)
                    strategy_sel.update_queries(miscls_set)
                    private_set = getPrivateSet(val_set, 0)
                    strategy_sel.update_privates(private_set)

            if(strategy=="SIM" or strategy=="SF"):
                if(sf.endswith("mi")):
                    if(feature=="classimb"):
                        #make a dataloader for the misclassifications - only for experiments with targets
                        miscls_set, miscls_set_targets = getQuerySet(val_set, val_class_err_idxs, sel_cls_idx, miscls)
                        strategy_sel.update_queries(miscls_set)
            elif(strategy=="AL"):
                if(sf=="glister-tss" or sf=="gradmatch-tss"):
                    miscls_set = getQuerySet(val_set, val_class_err_idxs, sel_cls_idx, miscls)
                    strategy_sel.update_queries(miscls_set)
                    print("reinit AL with targeted miscls samples")
            
            strategy_sel.update_model(model)
            subset = strategy_sel.select(budget)
            if(strategy=="WASSAL_Weighted" or strategy == "WASSAL_Hybrid" or strategy == "WASSAL_Refrain"):
                analyze_simplex(strategy_args, lake_set, strategy_sel.simplex_target, strategy_sel.simplex_refrain)

            print("#### Selection Complete, Now re-training with augmented subset ####")
            if(visualize_tsne):
                tsne_plt = tsne_smi(strategy_sel.unlabeled_data_embedding.cpu(),
                                    lake_set.targets,
                                    strategy_sel.query_embedding.cpu(),
                                    miscls_set_targets,
                                    subset)
                print("Computed TSNE plot of the selection")
            lake_subset_idxs = subset #indices wrt to lake that need to be removed from the lake
            perClsSel = getPerClassSel(true_lake_set, lake_subset_idxs, num_cls)
            print("Selection per class: {}".format((perClsSel)))
            res_dict['sel_per_cls'].append(perClsSel)
            
            # augment the train_set with selected indices from the lake
            train_set, lake_set, true_lake_set, add_val_set = aug_train_subset(train_set, lake_set, true_lake_set, subset, lake_subset_idxs, budget, False) #aug train with random if budget is not filled
            print("After augmentation, size of train_set: ", len(train_set), " unlabeled set: ", len(lake_set), " val set: ", len(val_set))
    
            # Reinit train and lake loaders with new splits and reinit the model
            trainloader = torch.utils.data.DataLoader(train_set, batch_size=trn_batch_size, shuffle=True, pin_memory=True)
            lakeloader = torch.utils.data.DataLoader(lake_set, batch_size=tst_batch_size, shuffle=False, pin_memory=True)
            model = create_model(model_name, num_cls, device, strategy_args['embedding_type'])
            optimizer = optimizer_without_scheduler(model, learning_rate)
                
        # Start training
        start_time = time.time()
        num_ep=1
#         while(num_ep<150):
        if(strategy=="WASSAL_Weighted" or strategy == "WASSAL_Hybrid" or strategy == "WASSAL_Refrain"):
            simplex_target, simplex_refrain = getSimplexes(strategy_sel.simplex_target, strategy_sel.simplex_refrain, lake_subset_idxs)
            strategy_sel.update_simplexes(simplex_target, simplex_refrain)
        
        while(full_trn_acc[i]<0.99 and num_ep<100):
            model.train()
            for batch_idx, (inputs, targets) in enumerate(trainloader):
                inputs, targets = inputs.to(device), targets.to(device, non_blocking=True)
                # Variables in Pytorch are differentiable.
                inputs, target = Variable(inputs), Variable(inputs)
                # This will zero out the gradients for this batch.
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                loss.backward()
                optimizer.step()
            
            if(strategy=="WASSAL_Weighted" or strategy == "WASSAL_Hybrid"):
                model, optimizer = train_classifier_on_weighted_labels(strategy_args, model, optimizer,
                                                                       lake_set,
                                                                       strategy_sel.simplex_target,
                                                                       strategy_sel.simplex_refrain)
            # scheduler.step()
          
            full_trn_loss = 0
            full_trn_correct = 0
            full_trn_total = 0
            model.eval()
            with torch.no_grad():
                for batch_idx, (inputs, targets) in enumerate(trainloader): #Compute Train accuracy
                    inputs, targets = inputs.to(device), targets.to(device, non_blocking=True)
                    outputs = model(inputs)
                    loss = criterion(outputs, targets)
                    full_trn_loss += loss.item()
                    _, predicted = outputs.max(1)
                    full_trn_total += targets.size(0)
                    full_trn_correct += predicted.eq(targets).sum().item()
                full_trn_acc[i] = full_trn_correct / full_trn_total
                print("Selection Epoch ", i, " Training epoch [" , num_ep, "]" , " Training Acc: ", full_trn_acc[i], end="\r")
                num_ep+=1
            timing[i] = time.time() - start_time
        with torch.no_grad():
            final_val_predictions = []
            final_val_classifications = []
            for batch_idx, (inputs, targets) in enumerate(valloader): #Compute Val accuracy
                inputs, targets = inputs.to(device), targets.to(device, non_blocking=True)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                val_loss += loss.item()
                _, predicted = outputs.max(1)
                val_total += targets.size(0)
                val_correct += predicted.eq(targets).sum().item()
                final_val_predictions += list(predicted.cpu().numpy())
                final_val_classifications += list(predicted.eq(targets).cpu().numpy())

            final_tst_predictions = []
            final_tst_classifications = []
            for batch_idx, (inputs, targets) in enumerate(tstloader): #Compute test accuracy
                inputs, targets = inputs.to(device), targets.to(device, non_blocking=True)
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                tst_loss += loss.item()
                _, predicted = outputs.max(1)
                tst_total += targets.size(0)
                tst_correct += predicted.eq(targets).sum().item()
                final_tst_predictions += list(predicted.cpu().numpy())
                final_tst_classifications += list(predicted.eq(targets).cpu().numpy())                
            val_acc[i] = val_correct / val_total
            tst_acc[i] = tst_correct / tst_total
            val_losses[i] = val_loss
            fulltrn_losses[i] = full_trn_loss
            tst_losses[i] = tst_loss
            full_val_acc = list(np.array(val_acc))
            full_timing = list(np.array(timing))
            res_dict["test_acc"].append(tst_acc[i]*100)
            print('Epoch:', i + 1, 'FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time:', full_trn_loss, full_trn_acc[i], val_loss, val_acc[i], tst_loss, tst_acc[i], timing[i])
            print("Gain in accuracy: ",res_dict['test_acc'][i]-res_dict['test_acc'][i-1])
        if(i==0): 
            print("Saving initial model") 
            torch.save(model.state_dict(), initModelPath) #save initial train model if not present
            
    #Compute the statistics of the final model
    if(computeErrorLog):
        print("**** Final Metrics after Targeted Learning ****")
        tst_err_log, val_err_log, val_class_err_idxs = find_err_per_class(test_set, val_set, final_val_classifications, final_val_predictions, final_tst_classifications, final_tst_predictions, all_logs_dir, sf+"_"+str(bud))
        csvlog.append([100-x for x in tst_err_log])
        val_csvlog.append([100-x for x in val_err_log])
        res_dict["all_class_acc"] = csvlog
        res_dict["all_val_class_acc"] = val_csvlog
        
    #Print overall acc improvement and rare class acc improvement, show that TL selected relevant points in space, is possible show some images
    print_final_results(res_dict, sel_cls_idx)
    print("Total gain in accuracy: ",res_dict['test_acc'][i]-res_dict['test_acc'][0])
    
#     tsne_plt.show()

# %%
from trust.strategies.wassal_refrain import WASSAL_Refrain
run_targeted_selection(data_name,
            datadir, 
            feature, 
            model_name, 
            budget, 
            split_cfg, 
            learning_rate, 
            run, 
            device, 
            computeClassErrorLog,
            "WASSAL_Refrain", h=0.2)
# Out:
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 run_targeted_selection(data_name,
#       2             datadir,
#       3             feature,
#       4             model_name,
#       5             budget,
#       6             split_cfg,
#       7             learning_rate,
#       8             run,
#       9             device,
#      10             computeClassErrorLog,
#      11             "WASSAL_Refrain", h=0.2)
#
# Cell In[9], line 99, in run_targeted_selection(dataset_name, datadir, feature, model_name, budget, split_cfg, learning_rate, run, device, computeErrorLog, strategy, sf, h)
#      97     strategy_args['target'] = 1
#      98     strategy_args['refrain'] = 0
# ---> 99     strategy_sel = WASSAL_Refrain(train_set, unlabeled_lake_set, val_set, model, num_cls, strategy_args)
#     100 if(strategy == "WASSAL_Weighted"):
#     101     # strategy_args['verbose'] = True
#     102     strategy_args['h'] = h
#
# File ~/trust/trust/strategies/wassal_refrain.py:39, in WASSAL_Refrain.__init__(self, labeled_dataset, unlabeled_dataset, query_dataset, net, nclasses, args)
#      37 def __init__(self, labeled_dataset, unlabeled_dataset, query_dataset,net, nclasses, args={}): #
# ---> 39     super(WASSAL_Refrain, self).__init__(labeled_dataset, unlabeled_dataset, net, nclasses, args)
#      40     self.query_dataset = query_dataset
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %% [markdown]
# # WASSAL

# %%
from trust.strategies.wassal import WASSAL

run_targeted_selection(data_name,
               datadir, 
               feature, 
               model_name, 
               budget, 
               split_cfg,
               learning_rate,
               run, 
               device, 
               computeClassErrorLog,
               "WASSAL")
# Out:
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# There are 1103 Unlabeled dataset
# Wassertein loss: 7.612239837646484
# length of unlabelled dataset 1103
# Totals Probability of the budget: tensor(0.5092, device='cuda:0', grad_fn=<SumBackward0>)
# selected indices len  5
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5823972523212433 0.990909090909091 2.4134458526968956 0.7 5.452548801898956 0.5753205128205128 1.8377118110656738
# Gain in accuracy:  17.14743589743589
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             40 |           33.08 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# There are 1098 Unlabeled dataset
# Wassertein loss: 9.813430786132812
# length of unlabelled dataset 1098
# Totals Probability of the budget: tensor(0.2139, device='cuda:0', grad_fn=<SumBackward0>)
# selected indices len  5
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7504393756389618 1.0 1.836968570947647 0.775 4.471828937530518 0.6762820512820513 1.8870866298675537
# Gain in accuracy:  10.096153846153861
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.73 |
# |       1 |             55 |           50.77 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# There are 1093 Unlabeled dataset
# Wassertein loss: 10.348426818847656
# length of unlabelled dataset 1093
# Totals Probability of the budget: tensor(0.1944, device='cuda:0', grad_fn=<SumBackward0>)
# selected indices len  5
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.163661614060402 0.9916666666666667 1.826027199625969 0.75 4.257856726646423 0.6458333333333334 1.692779541015625
# Gain in accuracy:  -3.0448717948717956
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.15 |
# |       1 |             50 |           45.64 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# There are 1088 Unlabeled dataset
# Wassertein loss: 11.50860595703125
# length of unlabelled dataset 1088
# Totals Probability of the budget: tensor(0.1621, device='cuda:0', grad_fn=<SumBackward0>)
# selected indices len  5
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6652978286147118 1.0 1.6608596444129944 0.8 3.9018445312976837 0.7419871794871795 1.9340660572052002
# Gain in accuracy:  9.615384615384613
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           93.16 |
# |       1 |             60 |           62.82 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# There are 1083 Unlabeled dataset
# Wassertein loss: 12.216779708862305
# length of unlabelled dataset 1083
# Totals Probability of the budget: tensor(0.1831, device='cuda:0', grad_fn=<SumBackward0>)
# selected indices len  5
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0095020979642868 0.9923076923076923 1.5186564475297928 0.825 4.0074068903923035 0.7163461538461539 1.7703700065612793
# Gain in accuracy:  -2.564102564102569
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.44 |
# |       1 |             65 |           57.95 |
# Gain in overall test accuracy:  17.14743589743589
# Gain in targeted test accuracy:  13.805
# Total gain in accuracy:  31.25

# %% [markdown]
# # WASSAL_Refrain

# %%
h = [i/10 for i in range(1,11)]
for i in range(len(h)):
    print("\n\n=================== h={} ===================".format(h[i]))
    run_targeted_selection(data_name,
                datadir, 
                feature, 
                model_name, 
                budget, 
                split_cfg, 
                learning_rate, 
                run, 
                device, 
                computeClassErrorLog,
                "WASSAL_Refrain", h=h[i])
# Out:
# =================== h=0.1 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:6.314939022064209, loss_1:3.810847282409668, loss_2:3.5757527351379395, loss_3:10.716609954833984, h=0.1
# no of target labels identified correctly: 32/260
# no of refrain labels identified correctly: 441/454
# Weight of target samples in simplex_target: 0.6379499435424805
# Weight of refrain samples in simplex_refrain: 0.9839538335800171
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4505055621266365 1.0 2.7721215337514877 0.7 6.387263774871826 0.530448717948718 1.830381155014038
# Gain in accuracy:  12.660256410256409
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             40 |           25.64 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:7.571905136108398, loss_1:4.613828182220459, loss_2:3.6222429275512695, loss_3:6.641656398773193, h=0.1
# no of target labels identified correctly: 36/389
# no of refrain labels identified correctly: 480/498
# Weight of target samples in simplex_target: 0.35489532351493835
# Weight of refrain samples in simplex_refrain: 0.9694246053695679
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7680734843015671 1.0 1.6981641352176666 0.75 3.8979479670524597 0.6939102564102564 1.9240756034851074
# Gain in accuracy:  16.34615384615384
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.73 |
# |       1 |             50 |           53.59 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:8.061713218688965, loss_1:5.075894832611084, loss_2:3.6105480194091797, loss_3:6.2473039627075195, h=0.1
# no of target labels identified correctly: 31/419
# no of refrain labels identified correctly: 463/477
# Weight of target samples in simplex_target: 0.22678542137145996
# Weight of refrain samples in simplex_refrain: 0.9838789701461792
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6881660744547844 1.0 1.6552721112966537 0.775 3.7573486864566803 0.7483974358974359 1.9352693557739258
# Gain in accuracy:  5.448717948717956
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             55 |           62.56 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:7.886137962341309, loss_1:5.005710601806641, loss_2:3.5491509437561035, loss_3:6.687231063842773, h=0.1
# no of target labels identified correctly: 28/374
# no of refrain labels identified correctly: 451/462
# Weight of target samples in simplex_target: 0.39174818992614746
# Weight of refrain samples in simplex_refrain: 0.9866158962249756
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8975267857313156 0.992 1.1836557388305664 0.875 2.742985814809799 0.8365384615384616 1.9282097816467285
# Gain in accuracy:  8.81410256410257
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           87.61 |
# |       1 |             80 |           81.28 |
# Total misclassified examples from imbalanced classes (Size of query set):  4
# loss:7.553651809692383, loss_1:4.423317909240723, loss_2:3.6543684005737305, loss_3:5.24034309387207, h=0.1
# no of target labels identified correctly: 26/479
# no of refrain labels identified correctly: 463/479
# Weight of target samples in simplex_target: 0.05382774397730827
# Weight of refrain samples in simplex_refrain: 0.9712443351745605
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0202098712325096 0.9923076923076923 2.103745073080063 0.725 4.7272645235061646 0.5785256410256411 1.7390763759613037
# Gain in accuracy:  -25.80128205128205
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             45 |           34.1  |
# Gain in overall test accuracy:  12.660256410256409
# Gain in targeted test accuracy:  10.299999999999997
# Total gain in accuracy:  17.467948717948723
#
#
# =================== h=0.2 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:4.675047874450684, loss_1:4.030623912811279, loss_2:3.3821864128112793, loss_3:13.688812255859375, h=0.2
# no of target labels identified correctly: 29/173
# no of refrain labels identified correctly: 269/278
# Weight of target samples in simplex_target: 0.6874233484268188
# Weight of refrain samples in simplex_refrain: 0.9947872161865234
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0093585848808289 0.990909090909091 1.8494001477956772 0.775 4.411200821399689 0.6794871794871795 1.6538808345794678
# Gain in accuracy:  27.56410256410257
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             55 |           50.77 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:5.776410102844238, loss_1:4.022880554199219, loss_2:3.412271022796631, loss_3:8.293706893920898, h=0.2
# no of target labels identified correctly: 25/237
# no of refrain labels identified correctly: 311/315
# Weight of target samples in simplex_target: 0.40719759464263916
# Weight of refrain samples in simplex_refrain: 0.9933015704154968
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3968980126082897 1.0 1.6451324373483658 0.775 3.9045430719852448 0.7211538461538461 1.925135850906372
# Gain in accuracy:  4.166666666666657
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             55 |           57.18 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:6.585723400115967, loss_1:4.825749397277832, loss_2:3.3719749450683594, loss_3:8.060005187988281, h=0.2
# no of target labels identified correctly: 32/312
# no of refrain labels identified correctly: 325/332
# Weight of target samples in simplex_target: 0.2703549265861511
# Weight of refrain samples in simplex_refrain: 0.9915344715118408
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4412938952445984 0.9916666666666667 2.825295001268387 0.6 6.740429580211639 0.4551282051282051 1.8982985019683838
# Gain in accuracy:  -26.602564102564102
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.57 |
# |       1 |             20 |           13.08 |
# Total misclassified examples from imbalanced classes (Size of query set):  16
# loss:6.095975875854492, loss_1:4.73830509185791, loss_2:3.425823450088501, loss_3:10.340763092041016, h=0.2
# no of target labels identified correctly: 24/212
# no of refrain labels identified correctly: 323/330
# Weight of target samples in simplex_target: 0.6123293042182922
# Weight of refrain samples in simplex_refrain: 0.9893235564231873
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5714003331959248 1.0 1.9465212002396584 0.775 4.269758105278015 0.7019230769230769 1.9739606380462646
# Gain in accuracy:  24.679487179487182
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             55 |           53.33 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:6.752282619476318, loss_1:4.994470596313477, loss_2:3.3800883293151855, loss_3:8.111383438110352, h=0.2
# no of target labels identified correctly: 25/288
# no of refrain labels identified correctly: 333/342
# Weight of target samples in simplex_target: 0.34287217259407043
# Weight of refrain samples in simplex_refrain: 0.9916002750396729
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.48459356650710106 1.0 1.611991062760353 0.775 3.98519229888916 0.7275641025641025 2.226470470428467
# Gain in accuracy:  2.564102564102555
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             55 |           57.95 |
# Gain in overall test accuracy:  27.56410256410257
# Gain in targeted test accuracy:  21.794999999999998
# Total gain in accuracy:  32.37179487179486
#
#
# =================== h=0.3 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:3.050759792327881, loss_1:4.288758277893066, loss_2:3.8761274814605713, loss_3:17.04708480834961, h=0.3
# no of target labels identified correctly: 25/95
# no of refrain labels identified correctly: 103/104
# Weight of target samples in simplex_target: 0.760479748249054
# Weight of refrain samples in simplex_refrain: 0.9999485015869141
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.36448218673467636 0.990909090909091 2.1622908003628254 0.7 5.493313431739807 0.5961538461538461 1.9505274295806885
# Gain in accuracy:  19.230769230769226
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             40 |           36.15 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:4.775271415710449, loss_1:4.467653274536133, loss_2:3.282090663909912, loss_3:9.914907455444336, h=0.3
# no of target labels identified correctly: 30/193
# no of refrain labels identified correctly: 158/158
# Weight of target samples in simplex_target: 0.5472761988639832
# Weight of refrain samples in simplex_refrain: 1.0
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.1544208526611328 1.0 1.5935167372226715 0.85 3.3967190086841583 0.7788461538461539 1.782386302947998
# Gain in accuracy:  18.269230769230774
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           91.03 |
# |       1 |             70 |           70    |
# Total misclassified examples from imbalanced classes (Size of query set):  6
# loss:5.753547668457031, loss_1:5.044215202331543, loss_2:3.176267623901367, loss_3:8.223115921020508, h=0.3
# no of target labels identified correctly: 22/340
# no of refrain labels identified correctly: 189/195
# Weight of target samples in simplex_target: 0.2482355237007141
# Weight of refrain samples in simplex_refrain: 0.9924355745315552
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7181989848613739 0.9916666666666667 1.3364934846758842 0.85 3.460918426513672 0.7708333333333334 1.927597999572754
# Gain in accuracy:  -0.801282051282044
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.44 |
# |       1 |             70 |           66.67 |
# Total misclassified examples from imbalanced classes (Size of query set):  6
# loss:4.728671550750732, loss_1:3.936832904815674, loss_2:3.3297688961029053, loss_3:8.459766387939453, h=0.3
# no of target labels identified correctly: 15/188
# no of refrain labels identified correctly: 221/224
# Weight of target samples in simplex_target: 0.11842337250709534
# Weight of refrain samples in simplex_refrain: 0.9973943829536438
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.49974285438656807 1.0 1.4242450594902039 0.825 3.5011792182922363 0.7692307692307693 1.9849698543548584
# Gain in accuracy:  -0.1602564102564088
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.87 |
# |       1 |             65 |           66.15 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:4.5273237228393555, loss_1:4.470832824707031, loss_2:3.213590621948242, loss_3:10.523666381835938, h=0.3
# no of target labels identified correctly: 15/145
# no of refrain labels identified correctly: 161/163
# Weight of target samples in simplex_target: 0.03497140109539032
# Weight of refrain samples in simplex_refrain: 0.9977244138717651
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0750680565834045 1.0 1.1159460544586182 0.85 3.016989052295685 0.8205128205128205 1.8204054832458496
# Gain in accuracy:  5.12820512820511
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           90.6  |
# |       1 |             75 |           76.92 |
# Gain in overall test accuracy:  19.230769230769226
# Gain in targeted test accuracy:  15.554999999999996
# Total gain in accuracy:  41.66666666666666
#
#
# =================== h=0.4 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:1.8260746002197266, loss_1:4.548158168792725, loss_2:4.446174621582031, loss_3:17.92064666748047, h=0.4
# no of target labels identified correctly: 22/60
# no of refrain labels identified correctly: 96/97
# Weight of target samples in simplex_target: 0.790334939956665
# Weight of refrain samples in simplex_refrain: 0.9624764323234558
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.26845720410346985 1.0 2.5741669796407223 0.675 6.294744849205017 0.5256410256410257 1.8962152004241943
# Gain in accuracy:  12.179487179487182
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             35 |           24.62 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:3.2890963554382324, loss_1:4.564488410949707, loss_2:3.721118211746216, loss_3:12.4912748336792, h=0.4
# no of target labels identified correctly: 22/83
# no of refrain labels identified correctly: 78/78
# Weight of target samples in simplex_target: 0.5576890707015991
# Weight of refrain samples in simplex_refrain: 0.9999999403953552
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6310874298214912 0.991304347826087 2.2190767154097557 0.65 5.206363379955292 0.5464743589743589 1.9737584590911865
# Gain in accuracy:  2.0833333333333215
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.57 |
# |       1 |             30 |           27.69 |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# loss:3.31746244430542, loss_1:5.3349833488464355, loss_2:4.389124393463135, loss_3:16.016613006591797, h=0.4
# no of target labels identified correctly: 13/55
# no of refrain labels identified correctly: 114/117
# Weight of target samples in simplex_target: 0.802251935005188
# Weight of refrain samples in simplex_refrain: 0.9990063309669495
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4202414005994797 1.0 1.265009067952633 0.85 3.4884486496448517 0.782051282051282 2.083483934402466
# Gain in accuracy:  23.557692307692314
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             70 |           67.95 |
# Total misclassified examples from imbalanced classes (Size of query set):  6
# loss:4.045323848724365, loss_1:4.747461795806885, loss_2:3.5325465202331543, loss_3:10.586710929870605, h=0.4
# no of target labels identified correctly: 6/63
# no of refrain labels identified correctly: 75/76
# Weight of target samples in simplex_target: 0.14036670327186584
# Weight of refrain samples in simplex_refrain: 0.9993152618408203
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4549971967935562 1.0 1.6359564661979675 0.775 3.943923205137253 0.7163461538461539 1.9887511730194092
# Gain in accuracy:  -6.570512820512818
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             55 |           56.41 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:3.876943349838257, loss_1:4.362299919128418, loss_2:3.4758572578430176, loss_3:9.903034210205078, h=0.4
# no of target labels identified correctly: 14/94
# no of refrain labels identified correctly: 114/116
# Weight of target samples in simplex_target: 0.18765723705291748
# Weight of refrain samples in simplex_refrain: 0.9984395503997803
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5023217611014843 1.0 2.153482146561146 0.725 4.510463833808899 0.6474358974358975 2.1291706562042236
# Gain in accuracy:  -6.891025641025635
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             45 |           44.62 |
# Gain in overall test accuracy:  12.179487179487182
# Gain in targeted test accuracy:  10.005000000000003
# Total gain in accuracy:  24.358974358974365
#
#
# =================== h=0.5 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:0.2272968292236328, loss_1:4.80291748046875, loss_2:4.682190418243408, loss_3:18.515621185302734, h=0.5
# no of target labels identified correctly: 16/34
# no of refrain labels identified correctly: 72/73
# Weight of target samples in simplex_target: 0.7603052854537964
# Weight of refrain samples in simplex_refrain: 0.9644993543624878
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7016730532050133 0.990909090909091 2.2269329354166985 0.7 5.25755649805069 0.5272435897435898 1.8941516876220703
# Gain in accuracy:  12.339743589743591
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             40 |           25.13 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:2.2964258193969727, loss_1:4.815677642822266, loss_2:3.727872133255005, loss_3:12.494247436523438, h=0.5
# no of target labels identified correctly: 8/23
# no of refrain labels identified correctly: 78/79
# Weight of target samples in simplex_target: 0.726595401763916
# Weight of refrain samples in simplex_refrain: 0.9998725652694702
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0751893892884254 1.0 1.599443331360817 0.775 3.7451861798763275 0.7467948717948718 1.7918815612792969
# Gain in accuracy:  21.955128205128204
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.44 |
# |       1 |             55 |           62.82 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:3.1071033477783203, loss_1:5.939637660980225, loss_2:4.187662124633789, loss_3:14.040393829345703, h=0.5
# no of target labels identified correctly: 3/26
# no of refrain labels identified correctly: 95/96
# Weight of target samples in simplex_target: 0.38357865810394287
# Weight of refrain samples in simplex_refrain: 0.9998462200164795
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5161330625414848 1.0 1.178035408258438 0.85 3.111402541399002 0.8076923076923077 2.1030352115631104
# Gain in accuracy:  6.089743589743591
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           91.88 |
# |       1 |             70 |           74.1  |
# Total misclassified examples from imbalanced classes (Size of query set):  6
# loss:3.1738195419311523, loss_1:4.909650802612305, loss_2:3.9126875400543213, loss_3:11.297037124633789, h=0.5
# no of target labels identified correctly: 5/25
# no of refrain labels identified correctly: 61/62
# Weight of target samples in simplex_target: 0.006960115395486355
# Weight of refrain samples in simplex_refrain: 0.9997124671936035
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6110869087278843 1.0 1.762082763016224 0.8 4.536711156368256 0.6378205128205128 2.007831335067749
# Gain in accuracy:  -16.987179487179496
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             60 |           43.33 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:2.8806047439575195, loss_1:6.12132453918457, loss_2:4.734673500061035, loss_3:15.950786590576172, h=0.5
# no of target labels identified correctly: 4/15
# no of refrain labels identified correctly: 103/104
# Weight of target samples in simplex_target: 0.3241136074066162
# Weight of refrain samples in simplex_refrain: 0.9644675850868225
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.93080934882164 0.9923076923076923 1.6203262954950333 0.775 3.9011170864105225 0.7243589743589743 1.8227181434631348
# Gain in accuracy:  8.653846153846153
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             55 |           57.18 |
# Gain in overall test accuracy:  12.339743589743591
# Gain in targeted test accuracy:  10.044999999999995
# Total gain in accuracy:  32.051282051282044
#
#
# =================== h=0.6 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-1.0900697708129883, loss_1:4.792851448059082, loss_2:5.002401351928711, loss_3:18.14220428466797, h=0.6
# no of target labels identified correctly: 18/38
# no of refrain labels identified correctly: 92/93
# Weight of target samples in simplex_target: 0.5848098993301392
# Weight of refrain samples in simplex_refrain: 0.9527670741081238
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.22554941847920418 1.0 3.390338968485594 0.575 8.017796635627747 0.40224358974358976 2.0628178119659424
# Gain in accuracy:  -0.1602564102564088
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.57 |
# |       1 |             15 |            4.62 |
# Total misclassified examples from imbalanced classes (Size of query set):  17
# loss:0.1245870590209961, loss_1:5.016210556030273, loss_2:4.440791606903076, loss_3:15.554025650024414, h=0.6
# no of target labels identified correctly: 15/23
# no of refrain labels identified correctly: 82/84
# Weight of target samples in simplex_target: 0.8466559648513794
# Weight of refrain samples in simplex_refrain: 0.9503691792488098
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.35992833971977234 0.991304347826087 2.4343413710594177 0.725 6.427201509475708 0.5368589743589743 1.984652042388916
# Gain in accuracy:  13.461538461538453
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             45 |           27.44 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:1.7780256271362305, loss_1:7.816245079040527, loss_2:5.14166259765625, loss_3:18.633136749267578, h=0.6
# no of target labels identified correctly: 7/17
# no of refrain labels identified correctly: 124/127
# Weight of target samples in simplex_target: 0.7943805456161499
# Weight of refrain samples in simplex_refrain: 0.9998266100883484
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.915375828742981 0.9916666666666667 1.7358657270669937 0.725 3.6178793907165527 0.7451923076923077 1.934119701385498
# Gain in accuracy:  20.833333333333343
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           94.87 |
# |       1 |             50 |           62.31 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:1.0634765625, loss_1:5.95244026184082, loss_2:5.189518928527832, loss_3:16.797470092773438, h=0.6
# no of target labels identified correctly: 12/28
# no of refrain labels identified correctly: 92/93
# Weight of target samples in simplex_target: 0.6080963611602783
# Weight of refrain samples in simplex_refrain: 0.9662062525749207
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.1331366151571274 0.992 1.474983885884285 0.875 3.45457860827446 0.7852564102564102 1.794907808303833
# Gain in accuracy:  4.006410256410248
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             75 |           68.46 |
# Total misclassified examples from imbalanced classes (Size of query set):  5
# loss:1.4002552032470703, loss_1:5.602663993835449, loss_2:5.174378395080566, loss_3:15.62797737121582, h=0.6
# no of target labels identified correctly: 6/16
# no of refrain labels identified correctly: 88/89
# Weight of target samples in simplex_target: 0.4921770989894867
# Weight of refrain samples in simplex_refrain: 0.9938988089561462
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5643122680485249 0.9923076923076923 1.1869526281952858 0.85 2.88067290186882 0.8205128205128205 2.033048152923584
# Gain in accuracy:  3.525641025641022
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           92.74 |
# |       1 |             70 |           75.64 |
# Gain in overall test accuracy:  -0.1602564102564088
# Gain in targeted test accuracy:  0.2149999999999963
# Total gain in accuracy:  41.66666666666666
#
#
# =================== h=0.7 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-2.16086483001709, loss_1:5.2316203117370605, loss_2:5.099546432495117, loss_3:17.845760345458984, h=0.7
# no of target labels identified correctly: 14/29
# no of refrain labels identified correctly: 95/96
# Weight of target samples in simplex_target: 0.5650515556335449
# Weight of refrain samples in simplex_refrain: 0.9803421497344971
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5094032064080238 0.990909090909091 2.287868544459343 0.725 5.701520919799805 0.5544871794871795 1.8896949291229248
# Gain in accuracy:  15.064102564102562
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             45 |           30    |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:0.05980396270751953, loss_1:8.734380722045898, loss_2:5.510759353637695, loss_3:20.264766693115234, h=0.7
# no of target labels identified correctly: 7/14
# no of refrain labels identified correctly: 106/111
# Weight of target samples in simplex_target: 0.775774359703064
# Weight of refrain samples in simplex_refrain: 0.9880563020706177
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8289448395371437 0.991304347826087 1.267649233341217 0.875 3.2091627418994904 0.8157051282051282 1.9751694202423096
# Gain in accuracy:  26.12179487179487
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           91.88 |
# |       1 |             75 |           75.38 |
# Total misclassified examples from imbalanced classes (Size of query set):  5
# loss:0.03345680236816406, loss_1:6.88797664642334, loss_2:6.213886737823486, loss_3:18.669153213500977, h=0.7
# no of target labels identified correctly: 7/23
# no of refrain labels identified correctly: 130/132
# Weight of target samples in simplex_target: 0.49909818172454834
# Weight of refrain samples in simplex_refrain: 0.9747614860534668
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5194457694888115 1.0 1.607773795723915 0.8 3.4886203706264496 0.7692307692307693 1.915102481842041
# Gain in accuracy:  -4.647435897435884
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             60 |           64.87 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:0.20993900299072266, loss_1:5.659493446350098, loss_2:6.327272891998291, loss_3:16.824039459228516, h=0.7
# no of target labels identified correctly: 12/65
# no of refrain labels identified correctly: 80/82
# Weight of target samples in simplex_target: 0.19318147003650665
# Weight of refrain samples in simplex_refrain: 0.9993901252746582
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.44503308832645416 1.0 1.591622717678547 0.825 3.9708275496959686 0.7099358974358975 2.0264692306518555
# Gain in accuracy:  -5.929487179487182
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             65 |           55.64 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:0.7947301864624023, loss_1:4.98198938369751, loss_2:4.136185169219971, loss_3:11.89063549041748, h=0.7
# no of target labels identified correctly: 5/29
# no of refrain labels identified correctly: 65/66
# Weight of target samples in simplex_target: 0.4207635521888733
# Weight of refrain samples in simplex_refrain: 0.9998854994773865
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0247760489583015 1.0 1.319207638502121 0.8 3.310145616531372 0.8028846153846154 1.8330469131469727
# Gain in accuracy:  9.294871794871796
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             60 |           70.51 |
# Gain in overall test accuracy:  15.064102564102562
# Gain in targeted test accuracy:  12.049999999999997
# Total gain in accuracy:  39.90384615384616
#
#
# =================== h=0.8 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-3.4537601470947266, loss_1:5.389576435089111, loss_2:5.108806610107422, loss_3:17.44017791748047, h=0.8
# no of target labels identified correctly: 18/37
# no of refrain labels identified correctly: 108/110
# Weight of target samples in simplex_target: 0.5666037797927856
# Weight of refrain samples in simplex_refrain: 0.9809890985488892
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5335643999278545 0.990909090909091 3.1082176193594933 0.6 7.358354687690735 0.4182692307692308 1.9166259765625
# Gain in accuracy:  1.4423076923076934
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             20 |            7.44 |
# Total misclassified examples from imbalanced classes (Size of query set):  16
# loss:-2.1179914474487305, loss_1:5.115578651428223, loss_2:4.8897504806518555, loss_3:15.154150009155273, h=0.8
# no of target labels identified correctly: 15/26
# no of refrain labels identified correctly: 96/98
# Weight of target samples in simplex_target: 0.5273559093475342
# Weight of refrain samples in simplex_refrain: 0.9686936736106873
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.1094350963830948 0.991304347826087 2.098040983080864 0.7 4.8936439752578735 0.5689102564102564 1.8390007019042969
# Gain in accuracy:  15.064102564102555
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             40 |           32.82 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:0.4185161590576172, loss_1:5.782825946807861, loss_2:4.834247589111328, loss_3:12.74819564819336, h=0.8
# no of target labels identified correctly: 15/25
# no of refrain labels identified correctly: 92/93
# Weight of target samples in simplex_target: 0.6785139441490173
# Weight of refrain samples in simplex_refrain: 0.996697187423706
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3007444925606251 1.0 2.997656997293234 0.65 7.4547722935676575 0.47115384615384615 2.109288215637207
# Gain in accuracy:  -9.775641025641022
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             30 |           15.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# loss:-1.156698226928711, loss_1:6.092494964599609, loss_2:7.408665657043457, loss_3:18.322322845458984, h=0.8
# no of target labels identified correctly: 16/44
# no of refrain labels identified correctly: 65/68
# Weight of target samples in simplex_target: 0.6845666170120239
# Weight of refrain samples in simplex_refrain: 0.9689189195632935
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5776583477854729 1.0 2.2206608057022095 0.7 4.906794846057892 0.6458333333333334 1.9945745468139648
# Gain in accuracy:  17.46794871794873
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             40 |           45.13 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:-1.0111074447631836, loss_1:5.0104265213012695, loss_2:4.914313316345215, loss_3:13.669809341430664, h=0.8
# no of target labels identified correctly: 9/21
# no of refrain labels identified correctly: 103/104
# Weight of target samples in simplex_target: 0.6107089519500732
# Weight of refrain samples in simplex_refrain: 0.9713952541351318
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.2366836369037628 0.9923076923076923 1.6307767629623413 0.775 3.721227079629898 0.7323717948717948 1.8136301040649414
# Gain in accuracy:  8.653846153846146
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             55 |           58.97 |
# Gain in overall test accuracy:  1.4423076923076934
# Gain in targeted test accuracy:  1.4149999999999991
# Total gain in accuracy:  32.8525641025641
#
#
# =================== h=0.9 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-4.832616806030273, loss_1:5.508388519287109, loss_2:5.321671485900879, loss_3:17.40297508239746, h=0.9
# no of target labels identified correctly: 16/36
# no of refrain labels identified correctly: 96/97
# Weight of target samples in simplex_target: 0.4782842993736267
# Weight of refrain samples in simplex_refrain: 0.9780380725860596
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3929074592888355 1.0 2.481870524585247 0.675 6.124278962612152 0.5336538461538461 1.9017565250396729
# Gain in accuracy:  12.980769230769226
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             35 |           26.15 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:-1.9012413024902344, loss_1:6.634138584136963, loss_2:10.209564208984375, loss_3:20.827714920043945, h=0.9
# no of target labels identified correctly: 15/63
# no of refrain labels identified correctly: 39/40
# Weight of target samples in simplex_target: 0.2518581748008728
# Weight of refrain samples in simplex_refrain: 0.9975178241729736
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3559793047606945 1.0 3.164755128324032 0.55 7.433006107807159 0.41025641025641024 1.9744207859039307
# Gain in accuracy:  -12.339743589743591
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             10 |            6.15 |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-3.6020889282226562, loss_1:5.401968002319336, loss_2:5.506760597229004, loss_3:16.123130798339844, h=0.9
# no of target labels identified correctly: 18/33
# no of refrain labels identified correctly: 81/82
# Weight of target samples in simplex_target: 0.6052279472351074
# Weight of refrain samples in simplex_refrain: 0.977449893951416
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5424932800233364 1.0 2.495396986603737 0.575 6.241142570972443 0.41346153846153844 1.9344756603240967
# Gain in accuracy:  0.3205128205128247
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             15 |            6.67 |
# Total misclassified examples from imbalanced classes (Size of query set):  17
# loss:-3.817424774169922, loss_1:7.324664115905762, loss_2:10.101585388183594, loss_3:23.604084014892578, h=0.9
# no of target labels identified correctly: 18/67
# no of refrain labels identified correctly: 48/48
# Weight of target samples in simplex_target: 0.34226614236831665
# Weight of refrain samples in simplex_refrain: 1.0000001192092896
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.39392128214240074 1.0 3.06026953086257 0.625 7.023580491542816 0.4807692307692308 2.003145933151245
# Gain in accuracy:  6.7307692307692335
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             25 |           17.69 |
# Total misclassified examples from imbalanced classes (Size of query set):  15
# loss:-1.9120025634765625, loss_1:6.574800491333008, loss_2:5.20249080657959, loss_3:15.2103271484375, h=0.9
# no of target labels identified correctly: 14/17
# no of refrain labels identified correctly: 84/84
# Weight of target samples in simplex_target: 0.7824622392654419
# Weight of refrain samples in simplex_refrain: 1.0
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8399119079113007 1.0 1.4814322739839554 0.825 3.800168812274933 0.7339743589743589 1.831106185913086
# Gain in accuracy:  25.320512820512818
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             65 |           58.21 |
# Gain in overall test accuracy:  12.980769230769226
# Gain in targeted test accuracy:  10.555
# Total gain in accuracy:  33.01282051282051
#
#
# =================== h=1.0 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-2.853994369506836, loss_1:6.550585746765137, loss_2:9.066710472106934, loss_3:18.471290588378906, h=1.0
# no of target labels identified correctly: 2/49
# no of refrain labels identified correctly: 51/54
# Weight of target samples in simplex_target: 0.053113169968128204
# Weight of refrain samples in simplex_refrain: 0.9472275972366333
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6432144194841385 0.990909090909091 3.5540101751685143 0.5 7.729739189147949 0.3798076923076923 1.7647020816802979
# Gain in accuracy:  -2.4038461538461604
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |          100    |
# |       1 |              0 |            0.77 |
# Total misclassified examples from imbalanced classes (Size of query set):  20
# loss:-2.1665782928466797, loss_1:7.001193046569824, loss_2:9.58691692352295, loss_3:18.754688262939453, h=1.0
# no of target labels identified correctly: 4/41
# no of refrain labels identified correctly: 62/65
# Weight of target samples in simplex_target: 0.028971850872039795
# Weight of refrain samples in simplex_refrain: 0.973076581954956
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.19691570289433002 1.0 4.907854177057743 0.5 11.616970658302307 0.375 2.1416139602661133
# Gain in accuracy:  -0.4807692307692264
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |             100 |
# |       1 |              0 |               0 |
# Total misclassified examples from imbalanced classes (Size of query set):  20
# loss:-3.700411796569824, loss_1:6.808625221252441, loss_2:8.038711547851562, loss_3:18.547748565673828, h=1.0
# no of target labels identified correctly: 17/61
# no of refrain labels identified correctly: 66/69
# Weight of target samples in simplex_target: 0.15232351422309875
# Weight of refrain samples in simplex_refrain: 0.9816993474960327
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.34963713586330414 0.9916666666666667 4.688468404114246 0.5 10.010557532310486 0.375 1.9092042446136475
# Gain in accuracy:  0.0
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |             100 |
# |       1 |              0 |               0 |
# Total misclassified examples from imbalanced classes (Size of query set):  20
# loss:-3.293447494506836, loss_1:6.721489906311035, loss_2:7.815974235534668, loss_3:17.83091163635254, h=1.0
# no of target labels identified correctly: 14/62
# no of refrain labels identified correctly: 68/69
# Weight of target samples in simplex_target: 0.17193754017353058
# Weight of refrain samples in simplex_refrain: 0.9865525364875793
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6076251976191998 0.992 3.0907667875289917 0.55 6.930275857448578 0.41025641025641024 1.7989234924316406
# Gain in accuracy:  3.525641025641022
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.57 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-3.289067268371582, loss_1:5.504123687744141, loss_2:5.007962226867676, loss_3:13.801153182983398, h=1.0
# no of target labels identified correctly: 20/24
# no of refrain labels identified correctly: 91/92
# Weight of target samples in simplex_target: 0.8243123292922974
# Weight of refrain samples in simplex_refrain: 0.9911108016967773
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5008831173181534 1.0 2.8795021250844 0.575 6.708078503608704 0.4326923076923077 2.0172979831695557
# Gain in accuracy:  2.2435897435897516
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.57 |
# |       1 |             15 |            9.49 |
# Gain in overall test accuracy:  -2.4038461538461604
# Gain in targeted test accuracy:  -1.4950000000000045
# Total gain in accuracy:  2.884615384615387

# %% [markdown]
# # WASSAL_Weighted

# %%
h = [i/10 for i in range(1,11)]
for i in range(len(h)):
    print("\n\n=================== h={} ===================".format(h[i]))
    run_targeted_selection(data_name,
                datadir, 
                feature, 
                model_name, 
                budget, 
                split_cfg, 
                learning_rate, 
                run, 
                device, 
                computeClassErrorLog,
                "WASSAL_Weighted", h=h[i])
# Out:
# =================== h=0.1 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:8.473557472229004, loss_1:3.7967963218688965, loss_2:5.683676719665527, loss_3:10.06915283203125, h=0.1
# no of target labels identified correctly: 34/242
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.6359267830848694
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6970895230770111 1.0 1.6325023919343948 0.775 3.8008221685886383 0.7419871794871795 5.595680475234985
# Gain in accuracy:  33.81410256410257
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.44 |
# |       1 |             55 |           62.05 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:9.622557640075684, loss_1:4.561600685119629, loss_2:5.6771955490112305, loss_3:6.162386417388916, h=0.1
# no of target labels identified correctly: 27/327
# no of refrain labels identified correctly: 1049/1098
# Weight of target samples in simplex_target: 0.3408278226852417
# Weight of refrain samples in simplex_refrain: 0.9553734064102173
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.5872012227773666 0.991304347826087 1.9837042689323425 0.725 4.2761035561561584 0.6842948717948718 4.609267234802246
# Gain in accuracy:  -5.769230769230774
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           93.16 |
# |       1 |             45 |           53.59 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:9.573258399963379, loss_1:4.476116180419922, loss_2:5.667091369628906, loss_3:5.699492454528809, h=0.1
# no of target labels identified correctly: 31/324
# no of refrain labels identified correctly: 1047/1093
# Weight of target samples in simplex_target: 0.40662717819213867
# Weight of refrain samples in simplex_refrain: 0.9579139947891235
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.1242639124393463 0.9916666666666667 1.384348064661026 0.9 2.9750336408615112 0.8333333333333334 5.748007774353027
# Gain in accuracy:  14.90384615384616
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           86.75 |
# |       1 |             85 |           81.28 |
# Total misclassified examples from imbalanced classes (Size of query set):  3
# loss:9.45287036895752, loss_1:4.249753475189209, loss_2:5.665599346160889, loss_3:4.624821662902832, h=0.1
# no of target labels identified correctly: 21/412
# no of refrain labels identified correctly: 1045/1088
# Weight of target samples in simplex_target: 0.03393736481666565
# Weight of refrain samples in simplex_refrain: 0.9604779481887817
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7959423437714577 1.0 1.2693386226892471 0.9 3.168940782546997 0.8060897435897436 5.729034662246704
# Gain in accuracy:  -2.724358974358978
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           92.74 |
# |       1 |             80 |           73.33 |
# Total misclassified examples from imbalanced classes (Size of query set):  4
# loss:10.204822540283203, loss_1:5.283851623535156, loss_2:5.666788578033447, loss_3:7.458176612854004, h=0.1
# no of target labels identified correctly: 23/208
# no of refrain labels identified correctly: 1040/1083
# Weight of target samples in simplex_target: 0.23135852813720703
# Weight of refrain samples in simplex_refrain: 0.9602954387664795
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6580657809972763 1.0 1.506661593914032 0.825 3.831727534532547 0.719551282051282 5.741510391235352
# Gain in accuracy:  -8.65384615384616
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             65 |           56.92 |
# Gain in overall test accuracy:  33.81410256410257
# Gain in targeted test accuracy:  26.364999999999995
# Total gain in accuracy:  31.570512820512818
#
#
# =================== h=0.2 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:7.3665876388549805, loss_1:3.8999104499816895, loss_2:5.683676719665527, loss_3:11.084999084472656, h=0.2
# no of target labels identified correctly: 34/150
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.671654224395752
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.373443216085434 0.990909090909091 2.1119620203971863 0.65 4.725273787975311 0.5560897435897436 4.672316551208496
# Gain in accuracy:  15.224358974358978
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             30 |           30.51 |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# loss:8.23305892944336, loss_1:4.239157199859619, loss_2:5.678926944732666, loss_3:8.425127029418945, h=0.2
# no of target labels identified correctly: 27/159
# no of refrain labels identified correctly: 1049/1098
# Weight of target samples in simplex_target: 0.6563628315925598
# Weight of refrain samples in simplex_refrain: 0.9553734064102173
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6313241869211197 1.0 1.3819702565670013 0.825 3.509645253419876 0.7788461538461539 5.588387727737427
# Gain in accuracy:  22.275641025641022
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           92.74 |
# |       1 |             65 |           68.97 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:8.450152397155762, loss_1:4.260529518127441, loss_2:5.675721168518066, loss_3:7.430489540100098, h=0.2
# no of target labels identified correctly: 15/133
# no of refrain labels identified correctly: 1049/1093
# Weight of target samples in simplex_target: 0.2669966518878937
# Weight of refrain samples in simplex_refrain: 0.959743857383728
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8314124420285225 1.0 1.5708436518907547 0.875 3.9828462302684784 0.7147435897435898 5.580674171447754
# Gain in accuracy:  -6.410256410256409
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.87 |
# |       1 |             75 |           57.44 |
# Total misclassified examples from imbalanced classes (Size of query set):  5
# loss:7.649318695068359, loss_1:3.923189163208008, loss_2:5.670403957366943, loss_3:9.72137451171875, h=0.2
# no of target labels identified correctly: 12/143
# no of refrain labels identified correctly: 1046/1088
# Weight of target samples in simplex_target: 0.06518588960170746
# Weight of refrain samples in simplex_refrain: 0.9613970518112183
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5120679289102554 1.0 2.021301418542862 0.775 4.490256279706955 0.6714743589743589 5.857802867889404
# Gain in accuracy:  -4.32692307692308
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             55 |           47.95 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:8.7778959274292, loss_1:4.476667881011963, loss_2:5.658935546875, loss_3:6.788535118103027, h=0.2
# no of target labels identified correctly: 22/231
# no of refrain labels identified correctly: 1041/1083
# Weight of target samples in simplex_target: 0.19903503358364105
# Weight of refrain samples in simplex_refrain: 0.9612188339233398
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8691713139414787 0.9923076923076923 1.3051020205020905 0.9 3.3247638940811157 0.782051282051282 5.751882314682007
# Gain in accuracy:  11.057692307692307
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           91.03 |
# |       1 |             85 |           70.51 |
# Gain in overall test accuracy:  15.224358974358978
# Gain in targeted test accuracy:  12.094999999999999
# Total gain in accuracy:  37.82051282051282
#
#
# =================== h=0.3 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:6.1704206466674805, loss_1:4.260685920715332, loss_2:5.683676719665527, loss_3:12.57980728149414, h=0.3
# no of target labels identified correctly: 22/76
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7414476871490479
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.47133374214172363 1.0 1.61717539280653 0.775 4.104622453451157 0.7003205128205128 5.6901633739471436
# Gain in accuracy:  29.647435897435884
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             55 |           54.1  |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:7.596443176269531, loss_1:4.216620922088623, loss_2:5.678926944732666, loss_3:7.663681983947754, h=0.3
# no of target labels identified correctly: 9/85
# no of refrain labels identified correctly: 1049/1098
# Weight of target samples in simplex_target: 0.20044520497322083
# Weight of refrain samples in simplex_refrain: 0.9553734064102173
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8923293873667717 0.991304347826087 1.7662854194641113 0.775 4.313702583312988 0.7051282051282052 5.6135032176971436
# Gain in accuracy:  0.4807692307692406
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           90.17 |
# |       1 |             60 |           58.72 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:7.8299760818481445, loss_1:4.720067024230957, loss_2:5.6657304763793945, loss_3:8.519405364990234, h=0.3
# no of target labels identified correctly: 16/93
# no of refrain labels identified correctly: 1045/1093
# Weight of target samples in simplex_target: 0.38964205980300903
# Weight of refrain samples in simplex_refrain: 0.956084132194519
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4751311093568802 0.9916666666666667 2.504926711320877 0.675 5.949553728103638 0.4967948717948718 5.5504984855651855
# Gain in accuracy:  -20.83333333333333
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             35 |           20.26 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:7.815464496612549, loss_1:4.552226543426514, loss_2:5.655282974243164, loss_3:7.973484992980957, h=0.3
# no of target labels identified correctly: 19/107
# no of refrain labels identified correctly: 1041/1088
# Weight of target samples in simplex_target: 0.692312479019165
# Weight of refrain samples in simplex_refrain: 0.9568015336990356
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8851570785045624 1.0 1.842688426375389 0.8 4.512231826782227 0.6025641025641025 4.7767345905303955
# Gain in accuracy:  10.576923076923073
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             60 |           38.46 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:8.377645492553711, loss_1:4.926216125488281, loss_2:5.649787902832031, loss_3:7.327860355377197, h=0.3
# no of target labels identified correctly: 21/234
# no of refrain labels identified correctly: 1040/1083
# Weight of target samples in simplex_target: 0.3041020929813385
# Weight of refrain samples in simplex_refrain: 0.9602954387664795
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7229515314102173 1.0 1.652247816324234 0.775 3.9169160425662994 0.7532051282051282 5.771915674209595
# Gain in accuracy:  15.064102564102562
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.44 |
# |       1 |             55 |           63.85 |
# Gain in overall test accuracy:  29.647435897435884
# Gain in targeted test accuracy:  23.459999999999997
# Total gain in accuracy:  34.93589743589743
#
#
# =================== h=0.4 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:4.891963958740234, loss_1:4.587002754211426, loss_2:5.683676719665527, loss_3:13.446788787841797, h=0.4
# no of target labels identified correctly: 19/44
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.8218039274215698
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.1901817694306374 0.990909090909091 1.6580812633037567 0.8 4.0125692486763 0.6987179487179487 4.652731418609619
# Gain in accuracy:  29.487179487179475
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           93.59 |
# |       1 |             60 |           55.64 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:6.065179824829102, loss_1:4.059288024902344, loss_2:5.673113822937012, loss_3:9.168055534362793, h=0.4
# no of target labels identified correctly: 5/22
# no of refrain labels identified correctly: 1049/1098
# Weight of target samples in simplex_target: 0.3670687973499298
# Weight of refrain samples in simplex_refrain: 0.9553734064102173
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5633320584893227 0.991304347826087 1.6947689801454544 0.75 4.109863460063934 0.7403846153846154 5.560862064361572
# Gain in accuracy:  4.166666666666686
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             50 |           60    |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:5.957533359527588, loss_1:4.438886642456055, loss_2:5.6619367599487305, loss_3:10.358224868774414, h=0.4
# no of target labels identified correctly: 10/27
# no of refrain labels identified correctly: 1046/1093
# Weight of target samples in simplex_target: 0.669914960861206
# Weight of refrain samples in simplex_refrain: 0.9569990634918213
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.40994174778461456 1.0 1.5986452847719193 0.8 4.235984981060028 0.7051282051282052 5.58899450302124
# Gain in accuracy:  -3.525641025641036
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             60 |           53.85 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:6.987803936004639, loss_1:4.598166465759277, loss_2:5.656959056854248, loss_3:8.168302536010742, h=0.4
# no of target labels identified correctly: 6/51
# no of refrain labels identified correctly: 1046/1088
# Weight of target samples in simplex_target: 0.14134250581264496
# Weight of refrain samples in simplex_refrain: 0.9613970518112183
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4779357807710767 0.992 2.1489757150411606 0.7 5.498026132583618 0.5865384615384616 5.774729013442993
# Gain in accuracy:  -11.858974358974358
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             40 |           34.36 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:6.61530065536499, loss_1:4.552988052368164, loss_2:5.659816265106201, loss_3:8.993760108947754, h=0.4
# no of target labels identified correctly: 7/44
# no of refrain labels identified correctly: 1042/1083
# Weight of target samples in simplex_target: 0.3138082027435303
# Weight of refrain samples in simplex_refrain: 0.9621422290802002
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5634236335754395 1.0 1.965821884572506 0.775 4.547713756561279 0.657051282051282 5.867739915847778
# Gain in accuracy:  7.051282051282051
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             55 |           46.15 |
# Gain in overall test accuracy:  29.487179487179475
# Gain in targeted test accuracy:  22.735
# Total gain in accuracy:  25.320512820512818
#
#
# =================== h=0.5 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:3.7151145935058594, loss_1:4.658563613891602, loss_2:5.683676719665527, loss_3:13.254251480102539, h=0.5
# no of target labels identified correctly: 10/16
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7037426233291626
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4241153746843338 1.0 1.8423848673701286 0.75 5.13468861579895 0.6458333333333334 5.669606924057007
# Gain in accuracy:  24.198717948717956
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             50 |           45.38 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:5.152431011199951, loss_1:4.413346290588379, loss_2:5.6775712966918945, loss_3:9.876973152160645, h=0.5
# no of target labels identified correctly: 6/20
# no of refrain labels identified correctly: 1048/1098
# Weight of target samples in simplex_target: 0.7360904216766357
# Weight of refrain samples in simplex_refrain: 0.9544626474380493
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4677390269935131 1.0 2.4000216647982597 0.55 5.507346868515015 0.5016025641025641 5.581121444702148
# Gain in accuracy:  -14.423076923076934
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.57 |
# |       1 |             10 |           20.51 |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:4.566163063049316, loss_1:4.962792873382568, loss_2:5.669399261474609, loss_3:12.132059097290039, h=0.5
# no of target labels identified correctly: 7/23
# no of refrain labels identified correctly: 1047/1093
# Weight of target samples in simplex_target: 0.7082110643386841
# Weight of refrain samples in simplex_refrain: 0.9579139947891235
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4889926575124264 0.9916666666666667 1.8442716524004936 0.75 4.550185322761536 0.6634615384615384 5.588188409805298
# Gain in accuracy:  16.18589743589743
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             50 |           46.92 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:5.970587730407715, loss_1:4.935917854309082, loss_2:5.667922496795654, loss_3:9.266504287719727, h=0.5
# no of target labels identified correctly: 5/12
# no of refrain labels identified correctly: 1046/1088
# Weight of target samples in simplex_target: 0.6088062524795532
# Weight of refrain samples in simplex_refrain: 0.9613970518112183
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8207652047276497 1.0 1.43310184776783 0.875 3.710509270429611 0.7580128205128205 5.7172064781188965
# Gain in accuracy:  9.455128205128204
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |            95.3 |
# |       1 |             75 |            64.1 |
# Total misclassified examples from imbalanced classes (Size of query set):  5
# loss:4.814011573791504, loss_1:5.231973648071289, loss_2:5.667157173156738, loss_3:12.170238494873047, h=0.5
# no of target labels identified correctly: 0/7
# no of refrain labels identified correctly: 1044/1083
# Weight of target samples in simplex_target: 0.0
# Weight of refrain samples in simplex_refrain: 0.9639889001846313
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.9160495921969414 1.0 1.8370593413710594 0.75 3.9698503017425537 0.7163461538461539 4.819204092025757
# Gain in accuracy:  -4.166666666666657
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             50 |           55.13 |
# Gain in overall test accuracy:  24.198717948717956
# Gain in targeted test accuracy:  19.099999999999998
# Total gain in accuracy:  31.25
#
#
# =================== h=0.6 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:2.429081916809082, loss_1:4.801527976989746, loss_2:5.683676719665527, loss_3:13.426871299743652, h=0.6
# no of target labels identified correctly: 8/14
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7209070324897766
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.40775618329644203 1.0 2.6416917480528355 0.7 6.369403719902039 0.5288461538461539 5.69269061088562
# Gain in accuracy:  12.5
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             40 |           25.38 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:4.688853740692139, loss_1:5.080832481384277, loss_2:5.677243232727051, loss_3:10.11536979675293, h=0.6
# no of target labels identified correctly: 7/11
# no of refrain labels identified correctly: 1050/1098
# Weight of target samples in simplex_target: 0.9338245987892151
# Weight of refrain samples in simplex_refrain: 0.9562841653823853
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.39328770712018013 1.0 1.7728345021605492 0.75 4.934942066669464 0.6410256410256411 5.52465033531189
# Gain in accuracy:  11.217948717948715
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             50 |           43.59 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:4.793784141540527, loss_1:4.6009111404418945, loss_2:5.661620140075684, loss_3:9.114578247070312, h=0.6
# no of target labels identified correctly: 2/9
# no of refrain labels identified correctly: 1050/1093
# Weight of target samples in simplex_target: 0.2892790138721466
# Weight of refrain samples in simplex_refrain: 0.9606587886810303
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5125407427549362 0.9916666666666667 1.2557735219597816 0.875 3.6447094678878784 0.7628205128205128 5.608841896057129
# Gain in accuracy:  12.179487179487168
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             75 |           64.87 |
# Total misclassified examples from imbalanced classes (Size of query set):  5
# loss:4.908630847930908, loss_1:4.272047996520996, loss_2:5.652682304382324, loss_3:8.3601655960083, h=0.6
# no of target labels identified correctly: 0/4
# no of refrain labels identified correctly: 1047/1088
# Weight of target samples in simplex_target: 0.0
# Weight of refrain samples in simplex_refrain: 0.9623161554336548
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0402573645114899 0.992 1.7675863951444626 0.75 4.455403923988342 0.6810897435897436 4.775965929031372
# Gain in accuracy:  -8.173076923076906
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             50 |           50.26 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:4.323104381561279, loss_1:5.494262218475342, loss_2:5.659083366394043, loss_3:11.383733749389648, h=0.6
# no of target labels identified correctly: 3/8
# no of refrain labels identified correctly: 1042/1083
# Weight of target samples in simplex_target: 0.3976668119430542
# Weight of refrain samples in simplex_refrain: 0.9621422290802002
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6980059817433357 0.9923076923076923 1.1091594994068146 0.85 3.137613981962204 0.8173076923076923 5.788570404052734
# Gain in accuracy:  13.621794871794862
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           89.32 |
# |       1 |             70 |           77.18 |
# Gain in overall test accuracy:  12.5
# Gain in targeted test accuracy:  10.169999999999995
# Total gain in accuracy:  41.34615384615384
#
#
# =================== h=0.7 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:1.2807197570800781, loss_1:4.985555648803711, loss_2:5.683676719665527, loss_3:13.412160873413086, h=0.7
# no of target labels identified correctly: 9/12
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.9329867362976074
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3926609978079796 1.0 2.342350274324417 0.7 5.930100977420807 0.5865384615384616 5.671860218048096
# Gain in accuracy:  18.269230769230766
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             40 |           35.13 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:3.459749698638916, loss_1:4.408450603485107, loss_2:5.6754608154296875, loss_3:9.463088989257812, h=0.7
# no of target labels identified correctly: 5/8
# no of refrain labels identified correctly: 1050/1098
# Weight of target samples in simplex_target: 0.6776705980300903
# Weight of refrain samples in simplex_refrain: 0.9562841653823853
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3653154782950878 1.0 1.7485478296875954 0.8 4.502728193998337 0.7051282051282052 5.586388826370239
# Gain in accuracy:  11.858974358974358
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.15 |
# |       1 |             60 |           55.13 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:3.476372718811035, loss_1:5.007680892944336, loss_2:5.661694049835205, loss_3:10.275716781616211, h=0.7
# no of target labels identified correctly: 4/8
# no of refrain labels identified correctly: 1049/1093
# Weight of target samples in simplex_target: 0.4754893481731415
# Weight of refrain samples in simplex_refrain: 0.959743857383728
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5650400295853615 0.9916666666666667 1.5946578457951546 0.825 3.8919780254364014 0.7435897435897436 5.555840253829956
# Gain in accuracy:  3.846153846153854
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             65 |           60.77 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:4.895105838775635, loss_1:4.6186017990112305, loss_2:5.650145530700684, loss_3:7.67663049697876, h=0.7
# no of target labels identified correctly: 1/5
# no of refrain labels identified correctly: 1046/1088
# Weight of target samples in simplex_target: 0.5068663358688354
# Weight of refrain samples in simplex_refrain: 0.9613970518112183
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.9152933806180954 0.992 1.5825891494750977 0.8 3.6921367049217224 0.7660256410256411 4.783959627151489
# Gain in accuracy:  2.2435897435897374
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             60 |           64.36 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:4.141891002655029, loss_1:5.926394462585449, loss_2:5.652007102966309, loss_3:10.623586654663086, h=0.7
# no of target labels identified correctly: 2/7
# no of refrain labels identified correctly: 1042/1083
# Weight of target samples in simplex_target: 0.35564786195755005
# Weight of refrain samples in simplex_refrain: 0.9621422290802002
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3450779803097248 1.0 1.8648815155029297 0.75 4.528538793325424 0.6971153846153846 5.743887424468994
# Gain in accuracy:  -6.891025641025649
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             50 |           52.31 |
# Gain in overall test accuracy:  18.269230769230766
# Gain in targeted test accuracy:  14.614999999999995
# Total gain in accuracy:  29.326923076923066
#
#
# =================== h=0.8 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:0.16324615478515625, loss_1:5.293149948120117, loss_2:5.683676719665527, loss_3:13.516975402832031, h=0.8
# no of target labels identified correctly: 11/16
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7817328572273254
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.38735969737172127 0.990909090909091 2.682879291474819 0.725 6.597550332546234 0.5673076923076923 5.558115243911743
# Gain in accuracy:  16.34615384615384
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             45 |           32.56 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:3.08223819732666, loss_1:5.682840347290039, loss_2:5.678891181945801, loss_3:10.349366188049316, h=0.8
# no of target labels identified correctly: 6/10
# no of refrain labels identified correctly: 1049/1098
# Weight of target samples in simplex_target: 0.7311921119689941
# Weight of refrain samples in simplex_refrain: 0.9553734064102173
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6246865317225456 0.991304347826087 2.1758944988250732 0.675 4.88299697637558 0.6714743589743589 5.666617155075073
# Gain in accuracy:  10.416666666666671
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             35 |           49.49 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:1.7141237258911133, loss_1:6.327571392059326, loss_2:5.671194076538086, loss_3:12.855802536010742, h=0.8
# no of target labels identified correctly: 4/11
# no of refrain labels identified correctly: 1049/1093
# Weight of target samples in simplex_target: 0.4582652449607849
# Weight of refrain samples in simplex_refrain: 0.959743857383728
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4117562919855118 1.0 1.8360485583543777 0.775 4.318582236766815 0.7003205128205128 5.554573059082031
# Gain in accuracy:  2.8846153846153726
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             55 |           53.08 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:3.752148151397705, loss_1:6.056604862213135, loss_2:5.673111438751221, loss_3:9.971960067749023, h=0.8
# no of target labels identified correctly: 1/8
# no of refrain labels identified correctly: 1047/1088
# Weight of target samples in simplex_target: 0.12977774441242218
# Weight of refrain samples in simplex_refrain: 0.9623161554336548
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.1811204850673676 0.992 1.8314016461372375 0.75 3.922053098678589 0.717948717948718 4.772648811340332
# Gain in accuracy:  1.7628205128205252
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             50 |           57.69 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:2.3570642471313477, loss_1:5.465928554534912, loss_2:5.651548385620117, loss_3:10.950515747070312, h=0.8
# no of target labels identified correctly: 6/13
# no of refrain labels identified correctly: 1043/1083
# Weight of target samples in simplex_target: 0.5582405924797058
# Weight of refrain samples in simplex_refrain: 0.9630656242370605
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5246120132505894 1.0 2.0023894868791103 0.7 4.61603969335556 0.6458333333333334 5.740543365478516
# Gain in accuracy:  -7.211538461538453
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             40 |           44.62 |
# Gain in overall test accuracy:  16.34615384615384
# Gain in targeted test accuracy:  12.905000000000001
# Total gain in accuracy:  24.198717948717956
#
#
# =================== h=0.9 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-1.0890960693359375, loss_1:5.7217206954956055, loss_2:5.683676719665527, loss_3:13.882770538330078, h=0.9
# no of target labels identified correctly: 10/16
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.6669914722442627
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.21901215333491564 1.0 3.626492142677307 0.65 9.246508240699768 0.47115384615384615 6.575490236282349
# Gain in accuracy:  6.730769230769226
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             30 |           16.92 |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# loss:1.704458236694336, loss_1:5.556901454925537, loss_2:5.683005332946777, loss_3:10.594943046569824, h=0.9
# no of target labels identified correctly: 13/17
# no of refrain labels identified correctly: 1047/1098
# Weight of target samples in simplex_target: 0.8483372926712036
# Weight of refrain samples in simplex_refrain: 0.9535518884658813
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5594984218478203 1.0 1.6902960538864136 0.775 4.286345958709717 0.6794871794871795 5.547430992126465
# Gain in accuracy:  20.833333333333343
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             55 |           50.77 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:2.8075389862060547, loss_1:6.120876312255859, loss_2:5.673190593719482, loss_3:9.985032081604004, h=0.9
# no of target labels identified correctly: 6/12
# no of refrain labels identified correctly: 1047/1093
# Weight of target samples in simplex_target: 0.3542182445526123
# Weight of refrain samples in simplex_refrain: 0.9579139947891235
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.44930049404501915 1.0 2.9500276893377304 0.625 7.3523112535476685 0.4358974358974359 5.789792060852051
# Gain in accuracy:  -24.358974358974365
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             25 |           10.51 |
# Total misclassified examples from imbalanced classes (Size of query set):  15
# loss:1.8636903762817383, loss_1:5.033553123474121, loss_2:5.6741132736206055, loss_3:9.826640129089355, h=0.9
# no of target labels identified correctly: 8/17
# no of refrain labels identified correctly: 1043/1088
# Weight of target samples in simplex_target: 0.5621329545974731
# Weight of refrain samples in simplex_refrain: 0.9586397409439087
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4051484540104866 1.0 2.0808901861310005 0.675 5.671879827976227 0.5528846153846154 5.721067428588867
# Gain in accuracy:  11.698717948717949
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             35 |           29.23 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:2.5593366622924805, loss_1:5.934185981750488, loss_2:5.6751556396484375, loss_3:10.055561065673828, h=0.9
# no of target labels identified correctly: 9/17
# no of refrain labels identified correctly: 1041/1083
# Weight of target samples in simplex_target: 0.5811117887496948
# Weight of refrain samples in simplex_refrain: 0.9612188339233398
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5098240971565247 1.0 1.966904379427433 0.725 4.790099859237671 0.657051282051282 5.775296688079834
# Gain in accuracy:  10.416666666666664
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             45 |           46.15 |
# Gain in overall test accuracy:  6.730769230769226
# Gain in targeted test accuracy:  5.299999999999997
# Total gain in accuracy:  25.320512820512818
#
#
# =================== h=1.0 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-2.130472183227539, loss_1:5.873909950256348, loss_2:5.683676719665527, loss_3:13.688058853149414, h=1.0
# no of target labels identified correctly: 10/17
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.5701719522476196
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.34794492833316326 0.990909090909091 3.2935481145977974 0.675 8.77090573310852 0.42467948717948717 5.597967147827148
# Gain in accuracy:  2.0833333333333286
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             35 |            9.49 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:1.1365718841552734, loss_1:4.60317325592041, loss_2:5.683005332946777, loss_3:9.149606704711914, h=1.0
# no of target labels identified correctly: 13/17
# no of refrain labels identified correctly: 1047/1098
# Weight of target samples in simplex_target: 0.8440525531768799
# Weight of refrain samples in simplex_refrain: 0.9535518884658813
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7880430743098259 0.991304347826087 1.3736965209245682 0.825 3.030746966600418 0.8301282051282052 5.595362424850464
# Gain in accuracy:  40.544871794871796
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           91.88 |
# |       1 |             65 |           77.69 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:1.6085338592529297, loss_1:6.937058448791504, loss_2:5.681641101837158, loss_3:11.01016616821289, h=1.0
# no of target labels identified correctly: 10/16
# no of refrain labels identified correctly: 1047/1093
# Weight of target samples in simplex_target: 0.6648019552230835
# Weight of refrain samples in simplex_refrain: 0.9579139947891235
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4834037385880947 1.0 2.0866480320692062 0.75 4.687669932842255 0.6522435897435898 5.562560081481934
# Gain in accuracy:  -17.788461538461533
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.73 |
# |       1 |             50 |           46.92 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:1.2290401458740234, loss_1:5.651730537414551, loss_2:5.680170059204102, loss_3:10.102860450744629, h=1.0
# no of target labels identified correctly: 8/13
# no of refrain labels identified correctly: 1045/1088
# Weight of target samples in simplex_target: 0.6403731107711792
# Weight of refrain samples in simplex_refrain: 0.9604779481887817
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.48234520107507706 1.0 1.866738524287939 0.8 4.763992249965668 0.6378205128205128 5.818423748016357
# Gain in accuracy:  -1.4423076923077005
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             60 |           43.33 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:1.6028823852539062, loss_1:7.411378860473633, loss_2:5.678561687469482, loss_3:11.487058639526367, h=1.0
# no of target labels identified correctly: 6/14
# no of refrain labels identified correctly: 1044/1083
# Weight of target samples in simplex_target: 0.5559607744216919
# Weight of refrain samples in simplex_refrain: 0.9639889001846313
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.057986095547676 0.9923076923076923 1.5798153728246689 0.775 4.036752939224243 0.6971153846153846 4.7858970165252686
# Gain in accuracy:  5.929487179487175
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             55 |           54.36 |
# Gain in overall test accuracy:  2.0833333333333286
# Gain in targeted test accuracy:  1.5849999999999937
# Total gain in accuracy:  29.326923076923066

# %% [markdown]
# # WASSAL_Hybrid

# %%
h = [i/10 for i in range(1,11)]
for i in range(len(h)):
    print("\n\n=================== h={} ===================".format(h[i]))
    run_targeted_selection(data_name,
                datadir, 
                feature, 
                model_name, 
                budget, 
                split_cfg, 
                learning_rate, 
                run, 
                device, 
                computeClassErrorLog,
                "WASSAL_Hybrid", h=h[i])
# Out:
# =================== h=0.1 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:8.473557472229004, loss_1:3.7967963218688965, loss_2:5.683676719665527, loss_3:10.06915283203125, h=0.1
# no of target labels identified correctly: 34/242
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.6359267830848694
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6216456741094589 1.0 1.338264912366867 0.825 3.875711977481842 0.7307692307692307 5.609513998031616
# Gain in accuracy:  32.69230769230768
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           93.59 |
# |       1 |             65 |           60.77 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:8.820455551147461, loss_1:3.834078311920166, loss_2:5.690309047698975, loss_3:7.0393218994140625, h=0.1
# no of target labels identified correctly: 18/244
# no of refrain labels identified correctly: 1045/1098
# Weight of target samples in simplex_target: 0.20403563976287842
# Weight of refrain samples in simplex_refrain: 0.9517303705215454
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8042113557457924 1.0 1.9961811006069183 0.725 4.399675607681274 0.6987179487179487 5.551328182220459
# Gain in accuracy:  -3.2051282051282044
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           93.59 |
# |       1 |             45 |           55.64 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:7.950552940368652, loss_1:3.60494065284729, loss_2:5.693254470825195, loss_3:13.476417541503906, h=0.1
# no of target labels identified correctly: 21/178
# no of refrain labels identified correctly: 1041/1093
# Weight of target samples in simplex_target: 0.7241630554199219
# Weight of refrain samples in simplex_refrain: 0.9524245262145996
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.48719001561403275 1.0 2.3761741295456886 0.725 5.526412189006805 0.6362179487179487 5.589947700500488
# Gain in accuracy:  -6.249999999999993
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.15 |
# |       1 |             45 |           44.1  |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:9.110085487365723, loss_1:4.020758152008057, loss_2:5.698118209838867, loss_3:6.0879011154174805, h=0.1
# no of target labels identified correctly: 33/307
# no of refrain labels identified correctly: 1036/1088
# Weight of target samples in simplex_target: 0.36324554681777954
# Weight of refrain samples in simplex_refrain: 0.9522058963775635
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.5037976056337357 0.992 2.0571641623973846 0.75 3.919572591781616 0.7307692307692307 4.848127841949463
# Gain in accuracy:  9.455128205128197
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           90.6  |
# |       1 |             50 |           62.56 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:8.21712875366211, loss_1:3.806074619293213, loss_2:5.701492786407471, loss_3:12.904382705688477, h=0.1
# no of target labels identified correctly: 23/179
# no of refrain labels identified correctly: 1032/1083
# Weight of target samples in simplex_target: 0.6940871477127075
# Weight of refrain samples in simplex_refrain: 0.9529085755348206
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.380300585180521 1.0 2.2671747282147408 0.775 5.848233222961426 0.5977564102564102 5.760812520980835
# Gain in accuracy:  -13.301282051282044
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.15 |
# |       1 |             55 |           37.95 |
# Gain in overall test accuracy:  32.69230769230768
# Gain in targeted test accuracy:  25.3
# Total gain in accuracy:  19.391025641025635
#
#
# =================== h=0.2 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:7.3665876388549805, loss_1:3.8999104499816895, loss_2:5.683676719665527, loss_3:11.084999084472656, h=0.2
# no of target labels identified correctly: 34/150
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.671654224395752
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.0850183367729187 1.0 1.8310405761003494 0.725 4.844997227191925 0.5993589743589743 4.6675379276275635
# Gain in accuracy:  19.551282051282044
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           93.16 |
# |       1 |             45 |           40    |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:8.20205020904541, loss_1:4.02913761138916, loss_2:5.686149597167969, loss_3:7.566184997558594, h=0.2
# no of target labels identified correctly: 24/183
# no of refrain labels identified correctly: 1045/1098
# Weight of target samples in simplex_target: 0.41990190744400024
# Weight of refrain samples in simplex_refrain: 0.9517303705215454
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6975169405341148 1.0 1.4793146550655365 0.875 3.5671342313289642 0.7916666666666666 5.554676532745361
# Gain in accuracy:  19.230769230769226
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           91.03 |
# |       1 |             75 |           72.05 |
# Total misclassified examples from imbalanced classes (Size of query set):  5
# loss:8.723419189453125, loss_1:4.639854907989502, loss_2:5.690673351287842, loss_3:8.035544395446777, h=0.2
# no of target labels identified correctly: 19/128
# no of refrain labels identified correctly: 1040/1093
# Weight of target samples in simplex_target: 0.5966288447380066
# Weight of refrain samples in simplex_refrain: 0.9515095949172974
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.2521025985479355 0.9916666666666667 1.9987637400627136 0.825 4.742559432983398 0.5833333333333334 4.676472902297974
# Gain in accuracy:  -20.83333333333332
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             65 |           35.38 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:8.089643478393555, loss_1:3.9397714138031006, loss_2:5.694705009460449, loss_3:7.724167823791504, h=0.2
# no of target labels identified correctly: 22/155
# no of refrain labels identified correctly: 1035/1088
# Weight of target samples in simplex_target: 0.4690069258213043
# Weight of refrain samples in simplex_refrain: 0.951286792755127
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.281237930059433 1.0 1.8825767040252686 0.775 4.486911058425903 0.6426282051282052 4.766928434371948
# Gain in accuracy:  5.929487179487175
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             55 |           44.87 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:7.743927001953125, loss_1:4.379111289978027, loss_2:5.69705867767334, loss_3:11.661213874816895, h=0.2
# no of target labels identified correctly: 18/123
# no of refrain labels identified correctly: 1032/1083
# Weight of target samples in simplex_target: 0.6712433099746704
# Weight of refrain samples in simplex_refrain: 0.9529085755348206
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.47996798530220985 1.0 1.903775967657566 0.725 5.5357785820961 0.5608974358974359 5.868309497833252
# Gain in accuracy:  -8.17307692307692
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             45 |           30.51 |
# Gain in overall test accuracy:  19.551282051282044
# Gain in targeted test accuracy:  14.699999999999996
# Total gain in accuracy:  15.705128205128204
#
#
# =================== h=0.3 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:6.1704206466674805, loss_1:4.260685920715332, loss_2:5.683676719665527, loss_3:12.57980728149414, h=0.3
# no of target labels identified correctly: 22/76
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7414476871490479
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5817824006080627 1.0 1.5106509774923325 0.8 3.808059900999069 0.7435897435897436 5.570103168487549
# Gain in accuracy:  33.97435897435898
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           91.88 |
# |       1 |             65 |           63.85 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:6.964419841766357, loss_1:4.076240539550781, loss_2:5.684725761413574, loss_3:9.321821212768555, h=0.3
# no of target labels identified correctly: 13/55
# no of refrain labels identified correctly: 1047/1098
# Weight of target samples in simplex_target: 0.4274984896183014
# Weight of refrain samples in simplex_refrain: 0.9535518884658813
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3670634292066097 1.0 2.611221991479397 0.6 5.668230831623077 0.5240384615384616 5.540644407272339
# Gain in accuracy:  -21.95512820512821
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             20 |           25.38 |
# Total misclassified examples from imbalanced classes (Size of query set):  16
# loss:5.789356708526611, loss_1:4.170032501220703, loss_2:5.687560081481934, loss_3:13.560785293579102, h=0.3
# no of target labels identified correctly: 19/56
# no of refrain labels identified correctly: 1043/1093
# Weight of target samples in simplex_target: 0.791265070438385
# Weight of refrain samples in simplex_refrain: 0.9542543888092041
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.47768813371658325 1.0 1.4898642003536224 0.775 4.186840921640396 0.7115384615384616 5.581637382507324
# Gain in accuracy:  18.750000000000007
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.73 |
# |       1 |             55 |           56.41 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:7.300154685974121, loss_1:4.078056812286377, loss_2:5.687472343444824, loss_3:8.217916488647461, h=0.3
# no of target labels identified correctly: 12/86
# no of refrain labels identified correctly: 1039/1088
# Weight of target samples in simplex_target: 0.36146795749664307
# Weight of refrain samples in simplex_refrain: 0.954963207244873
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.39034004881978035 1.0 1.9326082430779934 0.675 4.912109732627869 0.6538461538461539 5.736654996871948
# Gain in accuracy:  -5.769230769230774
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             35 |           45.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:6.333127975463867, loss_1:4.476072311401367, loss_2:5.683159828186035, loss_3:12.753679275512695, h=0.3
# no of target labels identified correctly: 19/61
# no of refrain labels identified correctly: 1035/1083
# Weight of target samples in simplex_target: 0.6991655826568604
# Weight of refrain samples in simplex_refrain: 0.9556787014007568
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4204413928091526 1.0 1.792896144092083 0.7 5.103349804878235 0.6217948717948718 5.761170148849487
# Gain in accuracy:  -3.2051282051282044
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             40 |           41.54 |
# Gain in overall test accuracy:  33.97435897435898
# Gain in targeted test accuracy:  25.984999999999996
# Total gain in accuracy:  21.794871794871796
#
#
# =================== h=0.4 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:4.891963958740234, loss_1:4.587002754211426, loss_2:5.683676719665527, loss_3:13.446788787841797, h=0.4
# no of target labels identified correctly: 19/44
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.8218039274215698
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3504074960947037 1.0 2.313679702579975 0.7 6.491880536079407 0.5016025641025641 5.72564697265625
# Gain in accuracy:  9.775641025641022
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             40 |           21.03 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:6.321138381958008, loss_1:4.117897987365723, loss_2:5.691070556640625, loss_3:8.719575881958008, h=0.4
# no of target labels identified correctly: 10/35
# no of refrain labels identified correctly: 1046/1098
# Weight of target samples in simplex_target: 0.5937288999557495
# Weight of refrain samples in simplex_refrain: 0.9526411294937134
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4888155609369278 1.0 1.4500515908002853 0.825 3.9716682136058807 0.7451923076923077 5.596478223800659
# Gain in accuracy:  24.358974358974365
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.73 |
# |       1 |             65 |           61.79 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:5.945822238922119, loss_1:4.679338455200195, loss_2:5.692111968994141, loss_3:11.064070701599121, h=0.4
# no of target labels identified correctly: 10/26
# no of refrain labels identified correctly: 1044/1093
# Weight of target samples in simplex_target: 0.5909008383750916
# Weight of refrain samples in simplex_refrain: 0.9551693201065063
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5806445777416229 1.0 1.9899205416440964 0.725 4.910754561424255 0.6041666666666666 5.565488338470459
# Gain in accuracy:  -14.10256410256411
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             45 |           37.69 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:6.414671897888184, loss_1:4.2119646072387695, loss_2:5.699146270751953, loss_3:8.741097450256348, h=0.4
# no of target labels identified correctly: 6/33
# no of refrain labels identified correctly: 1041/1088
# Weight of target samples in simplex_target: 0.5056123733520508
# Weight of refrain samples in simplex_refrain: 0.9568015336990356
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.584957804530859 1.0 1.5539751425385475 0.8 3.795925885438919 0.7387820512820513 5.724376440048218
# Gain in accuracy:  13.461538461538474
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             60 |           60.26 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# loss:6.340554237365723, loss_1:4.349364280700684, loss_2:5.705080032348633, loss_3:9.284725189208984, h=0.4
# no of target labels identified correctly: 6/37
# no of refrain labels identified correctly: 1037/1083
# Weight of target samples in simplex_target: 0.28382065892219543
# Weight of refrain samples in simplex_refrain: 0.957525372505188
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4864642024040222 1.0 2.2950304709374905 0.675 5.914328575134277 0.5096153846153846 5.872987985610962
# Gain in accuracy:  -22.91666666666668
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             35 |           22.31 |
# Gain in overall test accuracy:  9.775641025641022
# Gain in targeted test accuracy:  7.994999999999997
# Total gain in accuracy:  10.576923076923073
#
#
# =================== h=0.5 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:3.7151145935058594, loss_1:4.658563613891602, loss_2:5.683676719665527, loss_3:13.254251480102539, h=0.5
# no of target labels identified correctly: 10/16
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7037426233291626
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6621211841702461 0.990909090909091 1.834494724869728 0.75 5.2752832770347595 0.6266025641025641 4.65439248085022
# Gain in accuracy:  22.275641025641022
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.87 |
# |       1 |             50 |           43.33 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:5.013916969299316, loss_1:4.270489692687988, loss_2:5.685690879821777, loss_3:9.884527206420898, h=0.5
# no of target labels identified correctly: 4/14
# no of refrain labels identified correctly: 1047/1098
# Weight of target samples in simplex_target: 0.6573115587234497
# Weight of refrain samples in simplex_refrain: 0.9535518884658813
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.44002094492316246 1.0 2.9111367613077164 0.575 6.430505633354187 0.5480769230769231 5.6386048793792725
# Gain in accuracy:  -7.852564102564095
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             15 |           28.21 |
# Total misclassified examples from imbalanced classes (Size of query set):  17
# loss:3.5283050537109375, loss_1:4.640196800231934, loss_2:5.685354232788086, loss_3:13.594491958618164, h=0.5
# no of target labels identified correctly: 8/18
# no of refrain labels identified correctly: 1043/1093
# Weight of target samples in simplex_target: 0.7402692437171936
# Weight of refrain samples in simplex_refrain: 0.9542543888092041
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.37993917614221573 1.0 1.8420790806412697 0.75 5.341647446155548 0.6346153846153846 5.552253246307373
# Gain in accuracy:  8.653846153846146
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             50 |           44.36 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:4.96790075302124, loss_1:4.175410270690918, loss_2:5.688168525695801, loss_3:9.791356086730957, h=0.5
# no of target labels identified correctly: 3/11
# no of refrain labels identified correctly: 1038/1088
# Weight of target samples in simplex_target: 0.6275272369384766
# Weight of refrain samples in simplex_refrain: 0.9540441036224365
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5584022849798203 1.0 2.9747917391359806 0.65 6.199718415737152 0.6394230769230769 5.718999862670898
# Gain in accuracy:  0.4807692307692264
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             30 |           44.1  |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# loss:3.5827622413635254, loss_1:4.769864559173584, loss_2:5.687154769897461, loss_3:13.748515129089355, h=0.5
# no of target labels identified correctly: 6/17
# no of refrain labels identified correctly: 1033/1083
# Weight of target samples in simplex_target: 0.6807370185852051
# Weight of refrain samples in simplex_refrain: 0.9538319706916809
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8451453447341919 0.9923076923076923 1.9510387033224106 0.75 4.725068271160126 0.6298076923076923 4.8032543659210205
# Gain in accuracy:  -0.9615384615384599
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           95.3  |
# |       1 |             50 |           43.59 |
# Gain in overall test accuracy:  22.275641025641022
# Gain in targeted test accuracy:  17.22
# Total gain in accuracy:  22.59615384615384
#
#
# =================== h=0.6 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:2.429081916809082, loss_1:4.801527976989746, loss_2:5.683676719665527, loss_3:13.426871299743652, h=0.6
# no of target labels identified correctly: 8/14
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7209070324897766
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.29633950255811214 1.0 2.0207317285239697 0.75 5.503216862678528 0.6105769230769231 5.5650413036346436
# Gain in accuracy:  20.673076923076927
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.01 |
# |       1 |             50 |           39.49 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:4.036014556884766, loss_1:4.405094623565674, loss_2:5.692017555236816, loss_3:10.101829528808594, h=0.6
# no of target labels identified correctly: 4/8
# no of refrain labels identified correctly: 1045/1098
# Weight of target samples in simplex_target: 0.6743022799491882
# Weight of refrain samples in simplex_refrain: 0.9517303705215454
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3259625695645809 1.0 2.784959703683853 0.625 5.660610139369965 0.5977564102564102 5.62732720375061
# Gain in accuracy:  -1.2820512820512917
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.15 |
# |       1 |             25 |           37.95 |
# Total misclassified examples from imbalanced classes (Size of query set):  15
# loss:1.8598966598510742, loss_1:4.736001014709473, loss_2:5.697195529937744, loss_3:14.288833618164062, h=0.6
# no of target labels identified correctly: 8/12
# no of refrain labels identified correctly: 1040/1093
# Weight of target samples in simplex_target: 0.799613356590271
# Weight of refrain samples in simplex_refrain: 0.9515095949172974
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.40025774762034416 0.9916666666666667 2.912186224013567 0.675 7.467564165592194 0.4775641025641026 5.562560558319092
# Gain in accuracy:  -12.019230769230766
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             35 |           17.18 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:4.386417865753174, loss_1:5.132443904876709, loss_2:5.6992645263671875, loss_3:10.742151260375977, h=0.6
# no of target labels identified correctly: 9/13
# no of refrain labels identified correctly: 1035/1088
# Weight of target samples in simplex_target: 0.8981859683990479
# Weight of refrain samples in simplex_refrain: 0.951286792755127
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3194970339536667 1.0 1.8191495724022388 0.825 4.465458184480667 0.7067307692307693 5.8370325565338135
# Gain in accuracy:  22.91666666666668
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             65 |           54.62 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# loss:4.668558597564697, loss_1:5.969843864440918, loss_2:5.705212116241455, loss_3:11.677495956420898, h=0.6
# no of target labels identified correctly: 1/7
# no of refrain labels identified correctly: 1032/1083
# Weight of target samples in simplex_target: 0.3642682731151581
# Weight of refrain samples in simplex_refrain: 0.9529085755348206
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6222137250006199 0.9923076923076923 2.4966541565954685 0.675 6.210206091403961 0.48717948717948717 4.79090428352356
# Gain in accuracy:  -21.95512820512822
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             35 |           18.46 |
# Gain in overall test accuracy:  20.673076923076927
# Gain in targeted test accuracy:  16.37
# Total gain in accuracy:  8.333333333333329
#
#
# =================== h=0.7 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:1.2807197570800781, loss_1:4.985555648803711, loss_2:5.683676719665527, loss_3:13.412160873413086, h=0.7
# no of target labels identified correctly: 9/12
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.9329867362976074
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.25361792743206024 0.990909090909091 2.7450745552778244 0.7 6.987980127334595 0.5448717948717948 5.593966960906982
# Gain in accuracy:  14.102564102564095
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             40 |           28.46 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:3.6357169151306152, loss_1:5.057101249694824, loss_2:5.692882537841797, loss_3:10.163238525390625, h=0.7
# no of target labels identified correctly: 7/9
# no of refrain labels identified correctly: 1045/1098
# Weight of target samples in simplex_target: 0.9702786207199097
# Weight of refrain samples in simplex_refrain: 0.9517303705215454
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4376591183245182 0.991304347826087 1.950644463300705 0.725 4.5923959612846375 0.7035256410256411 5.601975202560425
# Gain in accuracy:  15.86538461538462
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             45 |           54.62 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:1.5530977249145508, loss_1:5.727079391479492, loss_2:5.693765640258789, loss_3:14.096782684326172, h=0.7
# no of target labels identified correctly: 8/10
# no of refrain labels identified correctly: 1040/1093
# Weight of target samples in simplex_target: 0.8194519877433777
# Weight of refrain samples in simplex_refrain: 0.9515095949172974
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3145060520619154 1.0 3.470129894092679 0.675 8.27746719121933 0.4567307692307692 5.755140781402588
# Gain in accuracy:  -24.679487179487182
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             35 |           14.62 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:3.5485758781433105, loss_1:4.64505672454834, loss_2:5.69846248626709, loss_3:9.707061767578125, h=0.7
# no of target labels identified correctly: 8/10
# no of refrain labels identified correctly: 1035/1088
# Weight of target samples in simplex_target: 0.870502233505249
# Weight of refrain samples in simplex_refrain: 0.951286792755127
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.9554876983165741 0.992 1.668602705001831 0.775 4.01856604218483 0.717948717948718 4.772642135620117
# Gain in accuracy:  26.121794871794876
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             55 |           56.41 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:1.7152891159057617, loss_1:6.8442301750183105, loss_2:5.70033073425293, loss_3:15.470389366149902, h=0.7
# no of target labels identified correctly: 9/12
# no of refrain labels identified correctly: 1030/1083
# Weight of target samples in simplex_target: 0.7783854603767395
# Weight of refrain samples in simplex_refrain: 0.9510618448257446
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.20228695310652256 1.0 3.7001828849315643 0.725 9.62624454498291 0.4775641025641026 5.769299030303955
# Gain in accuracy:  -24.03846153846154
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             45 |           17.95 |
# Gain in overall test accuracy:  14.102564102564095
# Gain in targeted test accuracy:  11.279999999999994
# Total gain in accuracy:  7.371794871794869
#
#
# =================== h=0.8 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:0.16324615478515625, loss_1:5.293149948120117, loss_2:5.683676719665527, loss_3:13.516975402832031, h=0.8
# no of target labels identified correctly: 11/16
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.7817328572273254
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.2939468286931515 0.990909090909091 3.072216123342514 0.725 7.8103920221328735 0.5032051282051282 5.574450492858887
# Gain in accuracy:  9.93589743589743
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             45 |           21.79 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:3.2004518508911133, loss_1:5.6094255447387695, loss_2:5.692052841186523, loss_3:10.126282691955566, h=0.8
# no of target labels identified correctly: 6/12
# no of refrain labels identified correctly: 1045/1098
# Weight of target samples in simplex_target: 0.6956943273544312
# Weight of refrain samples in simplex_refrain: 0.9517303705215454
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.342597808688879 1.0 2.8878346532583237 0.625 5.813065826892853 0.6330128205128205 5.606826305389404
# Gain in accuracy:  12.980769230769234
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             25 |           42.31 |
# Total misclassified examples from imbalanced classes (Size of query set):  15
# loss:-0.5682268142700195, loss_1:5.526941299438477, loss_2:5.692596912384033, loss_3:14.734705924987793, h=0.8
# no of target labels identified correctly: 9/14
# no of refrain labels identified correctly: 1040/1093
# Weight of target samples in simplex_target: 0.7231152057647705
# Weight of refrain samples in simplex_refrain: 0.9515095949172974
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3303763009607792 0.9916666666666667 3.5393681786954403 0.675 9.173057436943054 0.4551282051282051 5.582085609436035
# Gain in accuracy:  -17.78846153846154
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             35 |           13.85 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# loss:2.8124871253967285, loss_1:4.847892761230469, loss_2:5.694558143615723, loss_3:9.662454605102539, h=0.8
# no of target labels identified correctly: 9/13
# no of refrain labels identified correctly: 1035/1088
# Weight of target samples in simplex_target: 0.812868595123291
# Weight of refrain samples in simplex_refrain: 0.951286792755127
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.9675995483994484 0.992 1.702671304345131 0.725 4.189769744873047 0.719551282051282 5.037861585617065
# Gain in accuracy:  26.442307692307693
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.15 |
# |       1 |             45 |           57.44 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:1.4152679443359375, loss_1:5.997282981872559, loss_2:5.698247909545898, loss_3:12.85032844543457, h=0.8
# no of target labels identified correctly: 9/10
# no of refrain labels identified correctly: 1030/1083
# Weight of target samples in simplex_target: 0.9788076877593994
# Weight of refrain samples in simplex_refrain: 0.9510618448257446
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.29583111219108105 1.0 3.37064403668046 0.7 8.254672825336456 0.5048076923076923 5.729391098022461
# Gain in accuracy:  -21.474358974358978
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             40 |           22.31 |
# Gain in overall test accuracy:  9.93589743589743
# Gain in targeted test accuracy:  7.945
# Total gain in accuracy:  10.09615384615384
#
#
# =================== h=0.9 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-1.0890960693359375, loss_1:5.7217206954956055, loss_2:5.683676719665527, loss_3:13.882770538330078, h=0.9
# no of target labels identified correctly: 10/16
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.6669914722442627
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.31114544346928596 1.0 3.3234496973454952 0.7 8.20910370349884 0.49198717948717946 5.553714275360107
# Gain in accuracy:  8.814102564102562
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.15 |
# |       1 |             40 |           21.03 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:1.9624500274658203, loss_1:5.105003356933594, loss_2:5.692052841186523, loss_3:9.816228866577148, h=0.9
# no of target labels identified correctly: 9/13
# no of refrain labels identified correctly: 1045/1098
# Weight of target samples in simplex_target: 0.8440417647361755
# Weight of refrain samples in simplex_refrain: 0.9517303705215454
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4885120466351509 1.0 1.814343236386776 0.7 4.28301665186882 0.7051282051282052 5.553983449935913
# Gain in accuracy:  21.314102564102562
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             40 |           54.1  |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# loss:0.40001964569091797, loss_1:7.037928581237793, loss_2:5.692596912384033, loss_3:13.700563430786133, h=0.9
# no of target labels identified correctly: 9/15
# no of refrain labels identified correctly: 1040/1093
# Weight of target samples in simplex_target: 0.6881030797958374
# Weight of refrain samples in simplex_refrain: 0.9515095949172974
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.2914925795048475 1.0 3.062555657699704 0.725 7.732548534870148 0.49038461538461536 5.606957674026489
# Gain in accuracy:  -21.474358974358978
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             45 |           19.74 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:2.2254867553710938, loss_1:5.748091697692871, loss_2:5.694558143615723, loss_3:10.241292953491211, h=0.9
# no of target labels identified correctly: 6/11
# no of refrain labels identified correctly: 1035/1088
# Weight of target samples in simplex_target: 0.6534671783447266
# Weight of refrain samples in simplex_refrain: 0.951286792755127
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.30641476437449455 0.992 5.160807205364108 0.575 8.753227591514587 0.5208333333333334 6.716869115829468
# Gain in accuracy:  3.0448717948718027
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             15 |           24.36 |
# Total misclassified examples from imbalanced classes (Size of query set):  17
# loss:-1.301356315612793, loss_1:5.721986770629883, loss_2:5.698247909545898, loss_3:14.135101318359375, h=0.9
# no of target labels identified correctly: 10/16
# no of refrain labels identified correctly: 1030/1083
# Weight of target samples in simplex_target: 0.674591600894928
# Weight of refrain samples in simplex_refrain: 0.9510618448257446
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.23212811537086964 1.0 3.46418584510684 0.7 9.094239592552185 0.4983974358974359 5.789597272872925
# Gain in accuracy:  -2.2435897435897445
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             40 |           21.28 |
# Gain in overall test accuracy:  8.814102564102562
# Gain in targeted test accuracy:  6.710000000000001
# Total gain in accuracy:  9.455128205128204
#
#
# =================== h=1.0 ===================
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# loss:-2.130472183227539, loss_1:5.873909950256348, loss_2:5.683676719665527, loss_3:13.688058853149414, h=1.0
# no of target labels identified correctly: 10/17
# no of refrain labels identified correctly: 1050/1103
# Weight of target samples in simplex_target: 0.5701719522476196
# Weight of refrain samples in simplex_refrain: 0.9519492387771606
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.35268590971827507 1.0 3.6485995911061764 0.65 8.579634547233582 0.4407051282051282 5.5674989223480225
# Gain in accuracy:  3.685897435897431
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             30 |           12.05 |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# loss:1.1079397201538086, loss_1:5.255570411682129, loss_2:5.692052841186523, loss_3:9.839683532714844, h=1.0
# no of target labels identified correctly: 12/18
# no of refrain labels identified correctly: 1045/1098
# Weight of target samples in simplex_target: 0.6268596649169922
# Weight of refrain samples in simplex_refrain: 0.9517303705215454
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.2938582748174667 0.991304347826087 1.8142924904823303 0.775 4.173112452030182 0.6506410256410257 4.625750780105591
# Gain in accuracy:  20.99358974358975
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.44 |
# |       1 |             55 |           47.44 |
# Total misclassified examples from imbalanced classes (Size of query set):  9
# loss:2.26336669921875, loss_1:4.5988383293151855, loss_2:5.692596912384033, loss_3:8.028068542480469, h=1.0
# no of target labels identified correctly: 3/10
# no of refrain labels identified correctly: 1040/1093
# Weight of target samples in simplex_target: 0.28113749623298645
# Weight of refrain samples in simplex_refrain: 0.9515095949172974
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4374536909162998 1.0 1.5991805642843246 0.75 4.383316069841385 0.6955128205128205 5.557213068008423
# Gain in accuracy:  4.487179487179475
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             50 |           52.82 |
# Total misclassified examples from imbalanced classes (Size of query set):  10
# loss:0.6593532562255859, loss_1:5.723625659942627, loss_2:5.694558143615723, loss_3:10.758831024169922, h=1.0
# no of target labels identified correctly: 11/18
# no of refrain labels identified correctly: 1035/1088
# Weight of target samples in simplex_target: 0.6194884777069092
# Weight of refrain samples in simplex_refrain: 0.951286792755127
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.30684860050678253 1.0 2.300951022654772 0.725 6.577088415622711 0.47275641025641024 5.737115859985352
# Gain in accuracy:  -22.275641025641022
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             45 |           17.18 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# loss:2.0156288146972656, loss_1:5.058046817779541, loss_2:5.698247909545898, loss_3:8.740665435791016, h=1.0
# no of target labels identified correctly: 6/11
# no of refrain labels identified correctly: 1030/1083
# Weight of target samples in simplex_target: 0.5761817097663879
# Weight of refrain samples in simplex_refrain: 0.9510618448257446
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.43778660893440247 1.0 3.4292515330016613 0.55 7.260587692260742 0.5128205128205128 5.917071580886841
# Gain in accuracy:  4.0064102564102555
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             10 |           22.56 |
# Gain in overall test accuracy:  3.685897435897431
# Gain in targeted test accuracy:  2.864999999999995
# Total gain in accuracy:  10.89743589743589

# %% [markdown]
# # Submodular Mutual Information (SMI)
#
# We let $V$ denote the ground-set of $n$ data points $V = \{1, 2, 3,...,n \}$ and a set function $f:
#  2^{V} \xrightarrow{} \Re$. Given a set of items $A, B \subseteq V$, the submodular mutual information (MI)[1,3] is defined as $I_f(A; B) = f(A) + f(B) - f(A \cup B)$. Intuitively, this measures the similarity between $B$ and $A$ and we refer to $B$ as the query set.
#
# In [2], they extend MI to handle the case when the target can come from an auxiliary set $V^{\prime}$ different from the ground set $V$. For targeted data subset selection, $V$ is the source set of data instances and the target is a subset of data points (validation set or the specific set of examples of interest).
# Let $\Omega  = V \cup V^{\prime}$. We define a set function $f: 2^{\Omega} \rightarrow \Re$. Although $f$ is defined on $\Omega$, the discrete optimization problem will only be defined on subsets $A \subseteq V$. To find an optimal subset given a query set $Q \subseteq V^{\prime}$, we can define $g_{Q}(A) = I_f(A; Q)$, $A \subseteq V$ and maximize the same.

# %% [markdown]
# # FL1MI
#
# In the first variant of FL, we set the unlabeled dataset to be $V$. The SMI instantiation of FL1MI can be defined as:
# \begin{align}
# I_f(A;Q)=\sum_{i \in V}\min(\max_{j \in A}s_{ij}, \eta \max_{j \in Q}sq_{ij})
# \end{align}
#
# The first term in the min(.) of FL1MI models diversity, and the second term models query relevance. An increase in the value of $\eta$ causes the resulting summary to become more relevant to the query.

# %%
run_targeted_selection(data_name, 
               datadir, 
               feature, 
               model_name, 
               budget, 
               split_cfg, 
               learning_rate, 
               run, 
               device, 
               computeClassErrorLog,
               "SIM",'fl1mi')
# Out:
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 1.494605839252472 1.0 2.163745164871216 0.7 4.074429988861084 0.6842948717948718 1.5540852546691895
# Gain in accuracy:  28.044871794871796
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             40 |           51.54 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.9053108543157578 0.991304347826087 2.0644867047667503 0.7 4.388994216918945 0.6842948717948718 1.9624319076538086
# Gain in accuracy:  0.0
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             40 |           50.77 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8072046861052513 0.9916666666666667 1.3012299239635468 0.85 2.931908994913101 0.8237179487179487 1.923281192779541
# Gain in accuracy:  13.94230769230768
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           91.88 |
# |       1 |             75 |           76.67 |
# Total misclassified examples from imbalanced classes (Size of query set):  5
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.2995271496474743 1.0 1.4644356966018677 0.8 3.7675527930259705 0.7868589743589743 2.1942670345306396
# Gain in accuracy:  -3.685897435897431
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             60 |           67.95 |
# Total misclassified examples from imbalanced classes (Size of query set):  8
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6442102119326591 1.0 1.465890109539032 0.75 3.732639104127884 0.7708333333333334 2.008608341217041
# Gain in accuracy:  -1.602564102564088
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             50 |           64.87 |
# Gain in overall test accuracy:  28.044871794871796
# Gain in targeted test accuracy:  22.179999999999996
# Total gain in accuracy:  36.698717948717956

# %% [markdown]
# # FL2MI
#
# In the V2 variant, we set $D$ to be $V \cup Q$. The SMI instantiation of FL2MI can be defined as:
# \begin{align} \label{eq:FL2MI}
# I_f(A;Q)=\sum_{i \in Q} \max_{j \in A} sq_{ij} + \eta\sum_{i \in A} \max_{j \in Q} sq_{ij}
# \end{align}
# FL2MI is very intuitive for query relevance as well. It measures the representation of data points that are the most relevant to the query set and vice versa. It can also be thought of as a bidirectional representation score.

# %%
run_targeted_selection(data_name, 
               datadir, 
               feature, 
               model_name, 
               budget, 
               split_cfg, 
               learning_rate, 
               run, 
               device, 
               computeClassErrorLog, 
               "SIM",'fl2mi')
# Out:
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.9362472370266914 0.990909090909091 2.5454174876213074 0.6 4.980141520500183 0.5625 1.7099802494049072
# Gain in accuracy:  15.865384615384613
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             20 |           31.03 |
# Total misclassified examples from imbalanced classes (Size of query set):  16
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7579158246517181 1.0 2.1140620559453964 0.65 3.9757900536060333 0.7307692307692307 1.9650506973266602
# Gain in accuracy:  16.826923076923066
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           96.58 |
# |       1 |             30 |           58.97 |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.683073490858078 0.9916666666666667 1.841572068631649 0.725 4.082546442747116 0.7467948717948718 1.9027836322784424
# Gain in accuracy:  1.6025641025641164
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             45 |           61.03 |
# Total misclassified examples from imbalanced classes (Size of query set):  11
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5125001296401024 1.0 1.5166739895939827 0.825 3.7737230956554413 0.7708333333333334 2.0138566493988037
# Gain in accuracy:  2.4038461538461604
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.44 |
# |       1 |             65 |           64.87 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6758345142006874 0.9923076923076923 1.0819583237171173 0.9 2.9998027086257935 0.8333333333333334 2.0031931400299072
# Gain in accuracy:  6.25
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.02 |
# |       1 |             80 |           76.92 |
# Gain in overall test accuracy:  15.865384615384613
# Gain in targeted test accuracy:  12.780000000000001
# Total gain in accuracy:  42.948717948717956

# %% [markdown]
# # GCMI
#
# The SMI instantiation of graph-cut (GCMI) is defined as:
# \begin{align}
# I_f(A;Q)=2\sum_{i \in A} \sum_{j \in Q} sq_{ij}
# \end{align}
# Since maximizing GCMI maximizes the joint pairwise sum with the query set, it will lead to a subset similar to the query set $Q$.

# %%
run_targeted_selection(data_name, 
               datadir, 
               feature, 
               model_name, 
               budget, 
               split_cfg, 
               learning_rate, 
               run, 
               device, 
               computeClassErrorLog,
               "SIM",'gcmi')
# Out:
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.5016749575734138 1.0 3.0837676227092743 0.575 5.952355742454529 0.5192307692307693 1.8732843399047852
# Gain in accuracy:  11.53846153846154
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             15 |           23.59 |
# Total misclassified examples from imbalanced classes (Size of query set):  17
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [0, 5]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.35716190189123154 1.0 2.097223214805126 0.65 4.461298167705536 0.6858974358974359 2.138474225997925
# Gain in accuracy:  16.666666666666664
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             30 |           51.03 |
# Total misclassified examples from imbalanced classes (Size of query set):  14
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [1, 4]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.4504868611693382 1.0 1.4536596685647964 0.825 3.2963324785232544 0.7948717948717948 2.0891246795654297
# Gain in accuracy:  10.897435897435898
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           94.87 |
# |       1 |             65 |           70.26 |
# Total misclassified examples from imbalanced classes (Size of query set):  7
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6718520224094391 1.0 1.085551269352436 0.85 2.8971828520298004 0.8205128205128205 1.986684799194336
# Gain in accuracy:  2.564102564102555
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           88.46 |
# |       1 |             70 |           78.21 |
# Total misclassified examples from imbalanced classes (Size of query set):  6
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8659017384052277 0.9923076923076923 1.039537936449051 0.925 2.8965852856636047 0.8397435897435898 2.024247646331787
# Gain in accuracy:  1.923076923076934
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |             95 |           86.32 |
# |       1 |             90 |           82.56 |
# Gain in overall test accuracy:  11.53846153846154
# Gain in targeted test accuracy:  9.490000000000002
# Total gain in accuracy:  43.58974358974359

# %% [markdown]
# # LOGDETMI
#
# The SMI instantiation of LogDetMI can be defined as:
# \begin{align}
# I_f(A;Q)=\log\det(S_{A}) -\log\det(S_{A} - \eta^2 S_{A,Q}S_{Q}^{-1}S_{A,Q}^T)
# \end{align}
# $S_{A, B}$ denotes the cross-similarity matrix between the items in sets $A$ and $B$. The similarity matrix in constructed in such a way that the cross-similarity between $A$ and $Q$ is multiplied by $\eta$ to control the trade-off between query-relevance and diversity.

# %%
run_targeted_selection(data_name, 
               datadir, 
               feature, 
               model_name, 
               budget, 
               split_cfg, 
               learning_rate, 
               run, 
               device, 
               computeClassErrorLog,
               "SIM",'logdetmi')
# Out:
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# Total misclassified examples from imbalanced classes (Size of query set):  18
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [2, 3]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.6207961775362492 0.990909090909091 2.3597115576267242 0.675 5.599401354789734 0.5448717948717948 1.8795127868652344
# Gain in accuracy:  14.102564102564095
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             35 |           27.69 |
# Total misclassified examples from imbalanced classes (Size of query set):  13
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7338813096284866 1.0 2.2173076793551445 0.7 5.114694833755493 0.5769230769230769 1.9628219604492188
# Gain in accuracy:  3.2051282051282044
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             40 |           33.08 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.8426721543073654 1.0 2.1595431119203568 0.7 4.855187296867371 0.5833333333333334 1.9113891124725342
# Gain in accuracy:  0.6410256410256494
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.15 |
# |       1 |             40 |           33.85 |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [3, 2]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3864965531975031 1.0 2.0464462228119373 0.7 5.351746022701263 0.6458333333333334 2.0230236053466797
# Gain in accuracy:  6.250000000000007
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.72 |
# |       1 |             40 |           44.1  |
# Total misclassified examples from imbalanced classes (Size of query set):  12
# [||||||||||||||||||||]100% [Iteration 5 of 5]
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.9295998439192772 0.9923076923076923 1.9363768696784973 0.75 4.420189082622528 0.6666666666666666 1.8875794410705566
# Gain in accuracy:  2.0833333333333144
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           98.29 |
# |       1 |             50 |           47.69 |
# Gain in overall test accuracy:  14.102564102564095
# Gain in targeted test accuracy:  11.54
# Total gain in accuracy:  26.28205128205127

# %% [markdown]
# # Random

# %%
run_targeted_selection(data_name, 
               datadir, 
               feature, 
               model_name, 
               budget, 
               split_cfg, 
               learning_rate, 
               run, 
               device, 
               computeClassErrorLog,
               "random",'random')
# Out:
# pneumoniamnist Custom dataset stats: Train size:  105 Val size:  40 Lake size:  1103
# Indices of randomly selected classes for imbalance:  [0, 1]
# Initial training epoch
# Init model loaded from disk, skipping init training:  ./pneumoniamnist_ResNet18_0.0003_[0, 1]
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           97.86 |
# |       1 |             10 |            5.9  |
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  110  unlabeled set:  1098  val set:  40
# Epoch: 2 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.23316091857850552 1.0 3.789781089872122 0.525 9.139963030815125 0.3766025641025641 2.0883519649505615
# Gain in accuracy:  -2.724358974358978
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |           99.57 |
# |       1 |              5 |            0.51 |
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  115  unlabeled set:  1093  val set:  40
# Epoch: 3 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.2266674041748047 1.0 4.299237433820963 0.5 9.486879587173462 0.3782051282051282 2.1557106971740723
# Gain in accuracy:  0.1602564102564088
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |          100    |
# |       1 |              0 |            0.51 |
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  120  unlabeled set:  1088  val set:  40
# Epoch: 4 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.3495326414704323 0.9916666666666667 4.217708358541131 0.5 9.493446469306946 0.375 1.9031143188476562
# Gain in accuracy:  -0.3205128205128176
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |             100 |
# |       1 |              0 |               0 |
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [5, 0]
# After augmentation, size of train_set:  125  unlabeled set:  1083  val set:  40
# Epoch: 5 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.10383706539869308 1.0 6.643709217198193 0.5 13.593144059181213 0.375 2.415879964828491
# Gain in accuracy:  0.0
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |             100 |
# |       1 |              0 |               0 |
# #### Selection Complete, Now re-training with augmented subset ####
# Selection per class: [4, 1]
# After augmentation, size of train_set:  130  unlabeled set:  1078  val set:  40
# Epoch: 6 FullTrn,TrainAcc,ValLoss,ValAcc,TstLoss,TstAcc,Time: 0.7517432570457458 0.9923076923076923 3.282378241419792 0.5 6.994660913944244 0.38301282051282054 1.8142766952514648
# Gain in accuracy:  0.8012820512820511
# **** Final Metrics after Targeted Learning ****
# |   Class |   Val Accuracy |   Test Accuracy |
# |---------+----------------+-----------------|
# |       0 |            100 |          100    |
# |       1 |              0 |            1.28 |
# Gain in overall test accuracy:  -2.724358974358978
# Gain in targeted test accuracy:  -1.8400000000000034
# Total gain in accuracy:  -2.0833333333333357

# %% [markdown]
# # US

# %%
# run_targeted_selection(data_name, 
#                datadir, 
#                feature, 
#                model_name, 
#                budget, 
#                split_cfg, 
#                learning_rate, 
#                run, 
#                device, 
#                computeClassErrorLog,
#                "AL",'us')

# %% [markdown]
# # BADGE

# %%
# run_targeted_selection(data_name, 
#                datadir, 
#                feature, 
#                model_name, 
#                budget, 
#                split_cfg, 
#                learning_rate, 
#                run, 
#                device, 
#                computeClassErrorLog,
#                "AL",'badge')

# %% [markdown]
# # References
# [1] Rishabh Iyer, Ninad Khargoankar, Jeff Bilmes, and Himanshu Asnani. Submodular combinatorialinformation measures with applications in machine learning.arXiv preprint arXiv:2006.15412,2020
#
#
# [2] Kaushal V, Kothawade S, Ramakrishnan G, Bilmes J, Iyer R. PRISM: A Unified Framework of Parameterized Submodular Information Measures for Targeted Data Subset Selection and Summarization. arXiv preprint arXiv:2103.00128. 2021 Feb 27.
#
#
# [3] Anupam Gupta and Roie Levin. The online submodular cover problem. InACM-SIAM Symposiumon Discrete Algorithms, 2020
